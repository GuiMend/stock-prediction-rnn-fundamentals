# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
# Reading CSV file and transposing
dataset = pd.read_csv('grendene-indicadores-financeiros.csv').transpose()

# Setting columns names as the data's first column and removing that column
dataset.columns = dataset.iloc[0]
dataset = dataset.iloc[1:,]

# Transforming index to datetime
dataset['Trimestre'] = pd.to_datetime(dataset.index.values)
dataset = dataset.set_index('Trimestre')
dataset.head()
# Out:
# Data       LPA Lucro por Acao $ VPA Valor Patr por Acao$ Vendas por Acao $  \
# Trimestre
# 2003-12-31             0.648354                  2.21104           1.83187
# 2004-03-31                  NaN                  2.25414               NaN
# 2004-06-30                  NaN                  2.31287               NaN
# 2004-09-30                  NaN                 0.826589               NaN
# 2004-12-31             0.148932                 0.821877           2.52863
#
# Data       EBITDA por Acao $ Divida Total Liquida $ Divida Total Bruta $  \
# Trimestre
# 2003-12-31            1.0847             6.8965e+07          1.32215e+08
# 2004-03-31               NaN            1.31742e+08          1.34186e+08
# 2004-06-30               NaN            1.86723e+08          1.38671e+08
# 2004-09-30               NaN             1.1183e+08          1.43357e+08
# 2004-12-31          0.417843            1.56042e+08          1.48643e+08
#
# Data       Divida Bruta / Atv Tt % Divida Bruta / Pat Liq %  \
# Trimestre
# 2003-12-31                    14.5                     19.1
# 2004-03-31                    14.5                       19
# 2004-06-30                    14.7                     19.1
# 2004-09-30                    14.3                     19.3
# 2004-12-31                    14.1                     20.1
#
# Data       Divida Liq / Pat Liq % Estr Cap (D/D+Pat Liq) %  ...  \
# Trimestre                                                   ...
# 2003-12-31                     10                       16  ...
# 2004-03-31                   18.7                       16  ...
# 2004-06-30                   25.8                     16.1  ...
# 2004-09-30                     15                     16.2  ...
# 2004-12-31                   21.1                     16.7  ...
#
# Data       ROIC (IC inicial) % Invested Capital $ Rentab Invest Subsid %  \
# Trimestre
# 2003-12-31                 NaN        6.23761e+08                  210.8
# 2004-03-31                 NaN        5.74486e+08                    NaN
# 2004-06-30                 NaN        5.37906e+08                    NaN
# 2004-09-30                 NaN          6.321e+08                    NaN
# 2004-12-31                  18        5.83647e+08                    8.3
#
# Data       Alavancagem Financ x Alavancagem Operac x Capex (incl invest) $  \
# Trimestre
# 2003-12-31                  1.3                  2.1           2.49281e+08
# 2004-03-31                  NaN                  NaN                   NaN
# 2004-06-30                  NaN                  NaN                   NaN
# 2004-09-30                  NaN                  NaN                   NaN
# 2004-12-31                  0.7                    3            2.6874e+07
#
# Data       Depreciacao e amortiz $ Capex (inc inv)/Deprec %  \
# Trimestre
# 2003-12-31              9.9683e+07                    250.1
# 2004-03-31                     NaN                      NaN
# 2004-06-30                     NaN                      NaN
# 2004-09-30                     NaN                      NaN
# 2004-12-31              2.6894e+07                     99.9
#
# Data       Deprec / Imob e Intang % Fluxo de caixa livre $
# Trimestre
# 2003-12-31                      NaN                    NaN
# 2004-03-31                      NaN                    NaN
# 2004-06-30                      NaN                    NaN
# 2004-09-30                      NaN                    NaN
# 2004-12-31                     15.6                    NaN
#
# [5 rows x 56 columns]

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.plot(dataset['LPA Lucro por Acao $'], color = 'red', label = 'LPA')
plt.plot(dataset['VPA Valor Patr por Acao$'], color = 'red', label = 'VPA')
plt.plot(dataset['Vendas por Acao $'], color = 'green', label = 'Vendas')
plt.plot(dataset['EBITDA por Acao $'], color = 'blue', label = 'EBITDA')
plt.legend()
# Out:
# []

# %%
plt.plot(dataset['Divida Total Liquida $'], label = 'Divida Liq')
plt.plot(dataset['Divida Total Bruta $'], label = 'Divida Bruta')
