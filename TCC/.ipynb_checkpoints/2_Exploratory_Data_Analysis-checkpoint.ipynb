# %% [markdown]
# ## Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# Config: display 200 columns when printing dataset
pd.set_option("display.max_columns", 200)

# Importing to avoid warning when ploting data
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# **Import data and converting index to datetimeindex**

# %%
y = pd.read_csv('../data/grendene-cotacao.csv', index_col=0)
y.index = pd.to_datetime(y.index)
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 55 entries, 2005-12-31 to 2019-06-30
# Data columns (total 1 columns):
# Abertura proximo mes    55 non-null float64
# dtypes: float64(1)
# memory usage: 880.0 bytes

# %%
X = pd.read_csv('../data/grendene-indicadores-financeiros.csv', index_col=0)
X.index = pd.to_datetime(X.index)
X.head(2)
# Out:
#             LPA Lucro por Acao $  VPA Valor Patr por Acao$  Vendas por Acao $  \
# Trimestre
# 2005-12-31              0.093772                  0.947297            1.17377
# 2006-03-31              0.099011                  0.993100            1.15110
#
#             EBITDA por Acao $  Divida Total Liquida $  Divida Total Bruta $  \
# Trimestre
# 2005-12-31           0.170268             307976000.0           176130000.0
# 2006-03-31           0.167978             429948000.0           179115000.0
#
#             Divida Bruta / Atv Tt %  Divida Bruta / Pat Liq %  \
# Trimestre
# 2005-12-31                15.223819                 20.658787
# 2006-03-31                15.011012                 20.039942
#
#             Divida Liq / Pat Liq %  Estr Cap (D/D+Pat Liq) %  \
# Trimestre
# 2005-12-31                    36.1                 17.121660
# 2006-03-31                    48.1                 16.694395
#
#             EBIT / Divida Bruta %  EBIT / Divida Liquida %  \
# Trimestre
# 2005-12-31              71.764606                     41.0
# 2006-03-31              69.160595                     28.8
#
#             EBIT / Desp Fin Brut x  EBIT / Desp Fin Liq x  \
# Trimestre
# 2005-12-31                1.197573              27.743415
# 2006-03-31                1.112691               8.027281
#
#             Divida Bruta / Ebitda x  Divida liq / Ebitda x  \
# Trimestre
# 2005-12-31                 1.149366                    2.0
# 2006-03-31                 1.184780                    2.8
#
#             Divida CP / Divida Tt %  Exigivel Tt / Ativo Tt %  \
# Trimestre
# 2005-12-31                14.353035                 26.308261
# 2006-03-31                14.675488                 25.094534
#
#             Exigivel Tt / Pat Liq %  Exigivel Tt / Receita %  \
# Trimestre
# 2005-12-31                35.700420                28.812194
# 2006-03-31                33.501606                28.903175
#
#             Ativo Fixo / Pat Liq %  Investimentos / Pat Lq %  \
# Trimestre
# 2005-12-31               21.232349                  4.934158
# 2006-03-31               19.647904                  4.475884
#
#             Liquidez Geral x  Liquidez Corrente x  Liquidez Seca x  \
# Trimestre
# 2005-12-31          3.068141             6.044046         5.416786
# 2006-03-31          3.264853             6.616855         6.059050
#
#             Capital de Giro $  Capital Employed $  Prazo Med Estoques(dias)  \
# Trimestre
# 2005-12-31        774362000.0        1.028697e+09                 55.953193
# 2006-03-31        823459000.0        1.072905e+09                 48.486224
#
#             Prazo Med Forneced(dias)  Prazo Med Recebim (dias)  \
# Trimestre
# 2005-12-31                  9.285730                109.692700
# 2006-03-31                  7.947337                 88.797846
#
#             Ciclo Financeiro (dias)  Ciclo Operacional (dias)     EBITDA $  \
# Trimestre
# 2005-12-31               156.360163                165.645893  153241000.0
# 2006-03-31               129.336733                137.284069  151180000.0
#
#             LAIR + Desp Fin Liq $  Giro do Ativo x  Giro do Pat Liq x  \
# Trimestre
# 2005-12-31            126399000.0         0.913095           1.239073
# 2006-03-31            123877000.0         0.868228           1.159098
#
#             Margem Bruta %  Margem EBIT (Operac) %  Margem Liquida %  \
# Trimestre
# 2005-12-31       41.350425               11.965149          7.988978
# 2006-03-31       41.391616               11.957355          8.601434
#
#             Margem Ebitda %  ROA Rentab do Ativo %  ROE Rent Pat(pat final)%  \
# Trimestre
# 2005-12-31        14.506060               7.294693                  9.898929
# 2006-03-31        14.592805               7.468003                  9.969903
#
#             ROE Rent Pat(pat medio)%  ROE Rent Pat (pat inic)%  \
# Trimestre
# 2005-12-31                 10.600682                 11.409525
# 2006-03-31                 10.665227                 11.464809
#
#             ROIC (IC fim) %  ROIC (IC medio) %  ROIC (IC inicial) %  \
# Trimestre
# 2005-12-31        15.318531          14.788252            14.293458
# 2006-03-31        17.626437          17.154743            16.707637
#
#             Invested Capital $  Rentab Invest Subsid %  Alavancagem Financ x  \
# Trimestre
# 2005-12-31         544591000.0                    17.0              1.434441
# 2006-03-31         463842000.0                    24.4              1.614638
#
#             Alavancagem Operac x  Capex (incl invest) $  \
# Trimestre
# 2005-12-31              3.287077             42941000.0
# 2006-03-31              3.214032             34624000.0
#
#             Depreciacao e amortiz $  Capex (inc inv)/Deprec %  \
# Trimestre
# 2005-12-31               26842000.0                159.976902
# 2006-03-31               27303000.0                126.813903
#
#             Deprec / Imob e Intang %  Fluxo de caixa livre $
# Trimestre
# 2005-12-31                 15.845617             254085000.0
# 2006-03-31                 15.847762             244201000.0

# %% [markdown]
# **Joining input and output to a single df**

# %%
data_df = X
data_df['Abertura proximo mes'] = y['Abertura proximo mes']
data_df.head(2)
# Out:
#             LPA Lucro por Acao $  VPA Valor Patr por Acao$  Vendas por Acao $  \
# Trimestre
# 2005-12-31              0.093772                  0.947297            1.17377
# 2006-03-31              0.099011                  0.993100            1.15110
#
#             EBITDA por Acao $  Divida Total Liquida $  Divida Total Bruta $  \
# Trimestre
# 2005-12-31           0.170268             307976000.0           176130000.0
# 2006-03-31           0.167978             429948000.0           179115000.0
#
#             Divida Bruta / Atv Tt %  Divida Bruta / Pat Liq %  \
# Trimestre
# 2005-12-31                15.223819                 20.658787
# 2006-03-31                15.011012                 20.039942
#
#             Divida Liq / Pat Liq %  Estr Cap (D/D+Pat Liq) %  \
# Trimestre
# 2005-12-31                    36.1                 17.121660
# 2006-03-31                    48.1                 16.694395
#
#             EBIT / Divida Bruta %  EBIT / Divida Liquida %  \
# Trimestre
# 2005-12-31              71.764606                     41.0
# 2006-03-31              69.160595                     28.8
#
#             EBIT / Desp Fin Brut x  EBIT / Desp Fin Liq x  \
# Trimestre
# 2005-12-31                1.197573              27.743415
# 2006-03-31                1.112691               8.027281
#
#             Divida Bruta / Ebitda x  Divida liq / Ebitda x  \
# Trimestre
# 2005-12-31                 1.149366                    2.0
# 2006-03-31                 1.184780                    2.8
#
#             Divida CP / Divida Tt %  Exigivel Tt / Ativo Tt %  \
# Trimestre
# 2005-12-31                14.353035                 26.308261
# 2006-03-31                14.675488                 25.094534
#
#             Exigivel Tt / Pat Liq %  Exigivel Tt / Receita %  \
# Trimestre
# 2005-12-31                35.700420                28.812194
# 2006-03-31                33.501606                28.903175
#
#             Ativo Fixo / Pat Liq %  Investimentos / Pat Lq %  \
# Trimestre
# 2005-12-31               21.232349                  4.934158
# 2006-03-31               19.647904                  4.475884
#
#             Liquidez Geral x  Liquidez Corrente x  Liquidez Seca x  \
# Trimestre
# 2005-12-31          3.068141             6.044046         5.416786
# 2006-03-31          3.264853             6.616855         6.059050
#
#             Capital de Giro $  Capital Employed $  Prazo Med Estoques(dias)  \
# Trimestre
# 2005-12-31        774362000.0        1.028697e+09                 55.953193
# 2006-03-31        823459000.0        1.072905e+09                 48.486224
#
#             Prazo Med Forneced(dias)  Prazo Med Recebim (dias)  \
# Trimestre
# 2005-12-31                  9.285730                109.692700
# 2006-03-31                  7.947337                 88.797846
#
#             Ciclo Financeiro (dias)  Ciclo Operacional (dias)     EBITDA $  \
# Trimestre
# 2005-12-31               156.360163                165.645893  153241000.0
# 2006-03-31               129.336733                137.284069  151180000.0
#
#             LAIR + Desp Fin Liq $  Giro do Ativo x  Giro do Pat Liq x  \
# Trimestre
# 2005-12-31            126399000.0         0.913095           1.239073
# 2006-03-31            123877000.0         0.868228           1.159098
#
#             Margem Bruta %  Margem EBIT (Operac) %  Margem Liquida %  \
# Trimestre
# 2005-12-31       41.350425               11.965149          7.988978
# 2006-03-31       41.391616               11.957355          8.601434
#
#             Margem Ebitda %  ROA Rentab do Ativo %  ROE Rent Pat(pat final)%  \
# Trimestre
# 2005-12-31        14.506060               7.294693                  9.898929
# 2006-03-31        14.592805               7.468003                  9.969903
#
#             ROE Rent Pat(pat medio)%  ROE Rent Pat (pat inic)%  \
# Trimestre
# 2005-12-31                 10.600682                 11.409525
# 2006-03-31                 10.665227                 11.464809
#
#             ROIC (IC fim) %  ROIC (IC medio) %  ROIC (IC inicial) %  \
# Trimestre
# 2005-12-31        15.318531          14.788252            14.293458
# 2006-03-31        17.626437          17.154743            16.707637
#
#             Invested Capital $  Rentab Invest Subsid %  Alavancagem Financ x  \
# Trimestre
# 2005-12-31         544591000.0                    17.0              1.434441
# 2006-03-31         463842000.0                    24.4              1.614638
#
#             Alavancagem Operac x  Capex (incl invest) $  \
# Trimestre
# 2005-12-31              3.287077             42941000.0
# 2006-03-31              3.214032             34624000.0
#
#             Depreciacao e amortiz $  Capex (inc inv)/Deprec %  \
# Trimestre
# 2005-12-31               26842000.0                159.976902
# 2006-03-31               27303000.0                126.813903
#
#             Deprec / Imob e Intang %  Fluxo de caixa livre $  \
# Trimestre
# 2005-12-31                 15.845617             254085000.0
# 2006-03-31                 15.847762             244201000.0
#
#             Abertura proximo mes
# Trimestre
# 2005-12-31              1.164605
# 2006-03-31              0.902348

# %%
data_df.describe()
# Out:
#        LPA Lucro por Acao $  VPA Valor Patr por Acao$  Vendas por Acao $  \
# count             55.000000                 55.000000          55.000000
# mean               0.422502                  2.207155           1.920597
# std                0.202291                  0.869778           0.475797
# min                0.093772                  0.947297           1.136898
# 25%                0.278425                  1.491748           1.541123
# 50%                0.424009                  2.080369           1.888931
# 75%                0.608193                  2.920475           2.362088
# max                0.734614                  3.848956           2.558694
#
#        EBITDA por Acao $  Divida Total Liquida $  Divida Total Bruta $  \
# count          55.000000            5.500000e+01          5.500000e+01
# mean            0.382768            8.120089e+08          1.483202e+08
# std             0.131343            3.696917e+08          6.807302e+07
# min             0.167978            3.079760e+08          2.521900e+07
# 25%             0.264210            5.233115e+08          1.013870e+08
# 50%             0.371590            7.256910e+08          1.433290e+08
# 75%             0.488833            9.623870e+08          1.926200e+08
# max             0.601163            1.788544e+09          2.806070e+08
#
#        Divida Bruta / Atv Tt %  Divida Bruta / Pat Liq %  \
# count                55.000000                 55.000000
# mean                  7.582139                  9.530619
# std                   5.347223                  7.552951
# min                   1.204284                  1.343705
# 25%                   3.430279                  3.842131
# 50%                   5.387060                  6.296842
# 75%                  11.378660                 14.418440
# max                  20.039608                 28.447449
#
#        Divida Liq / Pat Liq %  Estr Cap (D/D+Pat Liq) %  \
# count               55.000000                 55.000000
# mean                41.996364                  8.301728
# std                 11.281400                  5.913216
# min                 16.300000                  1.325889
# 25%                 36.000000                  3.699973
# 50%                 44.400000                  5.923828
# 75%                 51.050000                 12.599714
# max                 58.600000                 22.147150
#
#        EBIT / Divida Bruta %  EBIT / Divida Liquida %  EBIT / Desp Fin Brut x  \
# count              55.000000                55.000000               55.000000
# mean              296.544423                42.750909                3.179685
# std               241.727769                20.207982                2.014545
# min                59.281074                17.800000                1.005855
# 25%               128.279669                30.500000                1.481554
# 50%               225.454755                34.500000                2.591381
# 75%               365.814322                48.250000                4.758365
# max              1130.536500               104.700000                8.336916
#
#        EBIT / Desp Fin Liq x  Divida Bruta / Ebitda x  Divida liq / Ebitda x  \
# count              55.000000                55.000000              55.000000
# mean                8.291007                 0.527072               2.445455
# std                12.599190                 0.385079               0.849143
# min                 1.217904                 0.080045               0.900000
# 25%                 1.981422                 0.240809               1.850000
# 50%                 3.112327                 0.399918               2.500000
# 75%                 7.859376                 0.717669               2.900000
# max                66.123575                 1.441778               4.700000
#
#        Divida CP / Divida Tt %  Exigivel Tt / Ativo Tt %  \
# count                55.000000                 55.000000
# mean                 58.363065                 15.809551
# std                  22.908597                  6.245707
# min                  14.353035                  7.600365
# 25%                  43.410867                 10.469318
# 50%                  61.940099                 13.977222
# 75%                  75.837597                 21.076798
# max                  93.421105                 30.840033
#
#        Exigivel Tt / Pat Liq %  Exigivel Tt / Receita %  \
# count                55.000000                55.000000
# mean                 19.466193                20.510411
# std                   9.467969                 7.664019
# min                   8.225536                10.513180
# 25%                  11.693675                14.002840
# 50%                  16.248280                18.163942
# 75%                  26.705981                25.224949
# max                  44.592319                40.129217
#
#        Ativo Fixo / Pat Liq %  Investimentos / Pat Lq %  Liquidez Geral x  \
# count               55.000000                 55.000000         55.000000
# mean                13.211276                  2.596819          6.272898
# std                  2.377265                  0.981592          2.153406
# min                 10.215064                  1.239122          2.773394
# 25%                 11.287728                  1.632718          4.190882
# 50%                 12.795878                  2.573282          6.242378
# 75%                 14.702017                  3.312828          8.215071
# max                 21.232349                  4.934158         11.478209
#
#        Liquidez Corrente x  Liquidez Seca x  Capital de Giro $  \
# count            55.000000        55.000000       5.500000e+01
# mean              7.031472         6.307432       1.533667e+09
# std               1.714528         1.504817       4.996697e+08
# min               4.339955         3.866314       7.743620e+08
# 25%               5.730377         5.202967       1.213430e+09
# 50%               6.576122         5.901331       1.432103e+09
# 75%               8.402295         7.399168       1.663603e+09
# max              11.486422        10.347103       2.721520e+09
#
#        Capital Employed $  Prazo Med Estoques(dias)  Prazo Med Forneced(dias)  \
# count        5.500000e+01                 55.000000                 55.000000
# mean         2.141186e+09                 67.852748                 11.424510
# std          7.650995e+08                 12.672321                  2.730025
# min          1.028697e+09                 48.486224                  6.969357
# 25%          1.544248e+09                 57.721718                  9.488763
# 50%          1.943983e+09                 65.304234                 11.074030
# 75%          2.791234e+09                 77.425904                 12.874740
# max          3.663703e+09                 96.723779                 19.313307
#
#        Prazo Med Recebim (dias)  Ciclo Financeiro (dias)  \
# count                 55.000000                55.000000
# mean                 112.399486               168.827725
# std                   20.352565                22.675326
# min                   71.214078               119.417460
# 25%                   97.165855               152.867776
# 50%                  116.408287               171.616513
# 75%                  124.529336               184.736112
# max                  157.338691               214.715809
#
#        Ciclo Operacional (dias)      EBITDA $  LAIR + Desp Fin Liq $  \
# count                 55.000000  5.500000e+01           5.500000e+01
# mean                 180.252235  3.450017e+08           3.081595e+08
# std                   23.702268  1.185572e+08           1.061766e+08
# min                  129.766277  1.511800e+08           1.238770e+08
# 25%                  163.287181  2.381425e+08           2.100680e+08
# 50%                  183.722473  3.344310e+08           3.145420e+08
# 75%                  197.305016  4.408505e+08           3.917015e+08
# max                  226.773442  5.423310e+08           4.814750e+08
#
#        Giro do Ativo x  Giro do Pat Liq x  Margem Bruta %  \
# count        55.000000          55.000000       55.000000
# mean          0.772610           0.925333       44.744089
# std           0.104697           0.155804        2.576497
# min           0.549327           0.623304       38.450072
# 25%           0.703847           0.804983       43.117348
# 50%           0.787776           0.974974       44.649490
# 75%           0.844036           1.049195       46.600120
# max           0.940863           1.239073       48.738416
#
#        Margem EBIT (Operac) %  Margem Liquida %  Margem Ebitda %  \
# count               55.000000         55.000000        55.000000
# mean                17.422844         20.695234        19.509570
# std                  2.632805          6.468661         2.727319
# min                 11.957355          7.988978        14.506060
# 25%                 15.551151         16.458603        17.345325
# 50%                 17.548920         21.545859        19.760416
# 75%                 19.807315         24.934856        22.012624
# max                 21.732305         32.308108        23.970569
#
#        ROA Rentab do Ativo %  ROE Rent Pat(pat final)%  \
# count              55.000000                 55.000000
# mean               15.613311                 18.354207
# std                 4.184918                  4.246470
# min                 7.294693                  9.898929
# 25%                13.503998                 15.335327
# 50%                16.984044                 19.437117
# 75%                19.047117                 21.341499
# max                21.125055                 25.813970
#
#        ROE Rent Pat(pat medio)%  ROE Rent Pat (pat inic)%  ROIC (IC fim) %  \
# count                 55.000000                 55.000000        55.000000
# mean                  19.323947                 20.414941        18.593271
# std                    4.492204                  4.802978         4.646469
# min                   10.600682                 11.234531        11.812623
# 25%                   15.940418                 16.655773        15.062097
# 50%                   20.601858                 21.915087        17.552261
# 75%                   22.480630                 23.798429        20.810646
# max                   28.184949                 31.035521        33.690273
#
#        ROIC (IC medio) %  ROIC (IC inicial) %  Invested Capital $  \
# count          55.000000            55.000000        5.500000e+01
# mean           19.402647            20.488023        1.180857e+09
# std             4.947701             5.671187        5.425970e+08
# min            12.072613            11.446675        4.638420e+08
# 25%            15.954172            16.733707        6.778525e+08
# 50%            18.249443            19.275603        1.047429e+09
# 75%            22.561577            24.109469        1.649128e+09
# max            35.658065            37.869988        2.191043e+09
#
#        Rentab Invest Subsid %  Alavancagem Financ x  Alavancagem Operac x  \
# count               55.000000             55.000000             55.000000
# mean                38.178665              1.636295              2.549384
# std                 46.616125              0.259136              0.369027
# min                  0.500000              1.205590              2.068983
# 25%                  9.250000              1.457513              2.197953
# 50%                 17.200000              1.626343              2.459608
# 75%                 56.000000              1.786534              2.827849
# max                193.300000              2.294588              3.345396
#
#        Capex (incl invest) $  Depreciacao e amortiz $  \
# count           5.500000e+01             5.500000e+01
# mean            7.264347e+07             3.684222e+07
# std             4.886559e+07             1.495961e+07
# min             1.219500e+07             1.953500e+07
# 25%             2.972600e+07             2.552350e+07
# 50%             5.079000e+07             2.995200e+07
# 75%             1.189450e+08             5.101550e+07
# max             1.844060e+08             6.368000e+07
#
#        Capex (inc inv)/Deprec %  Deprec / Imob e Intang %  \
# count                 55.000000                 55.000000
# mean                 183.332193                 14.286953
# std                   95.224127                  1.199345
# min                   44.827087                 11.967661
# 25%                  123.760164                 13.461117
# 50%                  169.571314                 14.516840
# 75%                  217.743840                 15.272405
# max                  489.413201                 16.287072
#
#        Fluxo de caixa livre $  Abertura proximo mes
# count            5.500000e+01             55.000000
# mean             2.685564e+08              3.597328
# std              1.133395e+08              2.503221
# min              1.623500e+07              0.723135
# 25%              1.907300e+08              1.390622
# 50%              2.540850e+08              3.239007
# 75%              3.526365e+08              4.893547
# max              5.110040e+08              8.839338

# %% [markdown]
# ### Scatterplot and Histograms
#
# We will start by creating a scatterplot matrix that will allow us to visualize the pair-wise relationships and correlations between the different features.
#
# It is also quite useful to have a quick overview of how the data is distributed and wheter it cointains or not outliers.

# %%
# Calculate and show pairplot

#sns.pairplot(data_df, height=2.5)
#plt.tight_layout()

# %% [markdown]
#     Results:

# %% [markdown]
# ### Correlation Matrix
#
# Create a correlation matrix to quantify and summarize the relationships between the variables.
#
# This correlation matrix is closely related witn covariance matrix, in fact it is a rescaled version of the covariance matrix, computed from standardize features.
#
# It is a square matrix (with the same number of columns and rows) that contains the Person’s r correlation coefficient.

# %%
#cols = data_df.columns
#fig, ax = plt.subplots(figsize=(50,50))

# Calculate and show correlation matrix
#cm = np.corrcoef(data_df.values.T)
#sns.set(font_scale=3)
#hm = sns.heatmap(cm,
#                cbar=True,
#                annot=True,
#                square=True,
#                fmt='.2f',
#                annot_kws={'size': 15},
#                yticklabels=cols,
#                xticklabels=cols,
#                ax=ax)

# %% [markdown]
#     Results: It's possible to observe that some features have a high correlation with the output "Abertura proximo mes"

# %%
fig, ax = plt.subplots(figsize=(30,100))
sns.set(font_scale=3)
hm2 = sns.heatmap(data_df.corr()[['Abertura proximo mes']].sort_values(by=['Abertura proximo mes'],ascending=False), annot=True, vmin=-1, vmax=1, linewidths=.5)

# %%
data_df.hist(figsize=(50, 50))
plt.tight_layout()

# %%
# Imports 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# scale the stock price
ss_price = StandardScaler()
y_train = ss_price.fit_transform(y_train)
y_test = ss_price.transform(y_test)
