# %% [markdown]
# ## Tuning best model with best optimizer
#
#
# Tune loss function:
#
#     1) relu
#
#     2) elu
#
#     3) linear
#
#     4) softmax
#
#     5) softplus
#
#     6) tanh
#
#     7) sigmoid
#
#
# #### A) Base model for activation function tuning: Deep Feed Forward NN (Best model from optimizer tuning)
#
#   80% train / 20% test / 0% validation split
#
# **kernel_initializer:** glorot_normal
#
# **layers:** input(X columns), (X columns * 1.5), (X columns * 1.5), output(1)
#
# **loss:** MSE
#
# **optimizer:** adam

# %%
import tcc_utils
import tratamento_dados_empresa
from keras.initializers import glorot_normal as gl_normal, glorot_uniform as gl_uni, RandomUniform as rnd_uni

x_csv_path = '../data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = '../data/grendene-cotacao-raw.csv'

X = tratamento_dados_empresa.treat_economatica_indicadores_financeiros(x_csv_path)

# Spliting test / train and Feature Scaling
x_train, x_test, y_train, y_test, x_scaler, y_scaler = tratamento_dados_empresa. \
    get_scaled_splits_and_scaler(x_csv_path, y_csv_path, 0.2, 0)

number_hidden_layer = round(x_train.shape[1]*1.5)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 1) Relu
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>'relu'</font>, <font color=red>'relu'</font>, output(none)
#
# #### <font color=green>Best activation function: ReLu</font>
# <font color=green>MSE of training: 0.0004275373886974359
#
# MSE of testing: 0.12102432548999786
#
# 1st quartile: 11.378343% | Median: 13.484112% | 3rd quartile: 18.042534% </font>

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['relu', 'relu']
# Create model
deep_model = tcc_utils.deep_model(x_train, glorot_normal, layers, activations)
# Fit model
deep_history = deep_model.fit(x_train, y_train, epochs=40, verbose=0)
# Evaluating model
tcc_utils.evaluate_model(deep_model, deep_history, x_train, y_train,
                         x_test, y_test, X, y_scaler)
# Out:
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 84)                4788
# _________________________________________________________________
# dense_2 (Dense)              (None, 84)                7140
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 85
# =================================================================
# Total params: 12,013
# Trainable params: 12,013
# Non-trainable params: 0
# _________________________________________________________________
# None
# MSE of training: 0.0004275373886974359
# MSE of testing: 0.12102432548999786
#     Prediction      Real     % error
# 8     7.452421  8.491036   12.231897
# 0     6.881386  8.075241   14.784137
# 7     5.447742  5.156991    5.637995
# 9     4.202127  4.785659   12.193334
# 2     5.238497  4.616062   13.484112
# 1     3.023895  3.669486   17.593496
# 6     3.860484  3.491649   10.563353
# 3     2.839289  3.003443    5.465518
# 10    1.123129  1.377930   18.491571
# 5     2.419888  0.900556  168.710373
# 4    -0.746734  0.667981  211.789637
# count     11.000000
# mean      44.631402
# std       72.752910
# min        5.465518
# 25%       11.378343
# 50%       13.484112
# 75%       18.042534
# max      211.789637
# Name: % error, dtype: float64

# %% [markdown]
# ### 2) Elu
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>'elu'</font>, <font color=red>'elu'</font>, output(none)

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['elu', 'elu']
# Create model
deep_model = tcc_utils.deep_model(x_train, glorot_normal, layers, activations)
# Fit model
deep_history = deep_model.fit(x_train, y_train, epochs=40, verbose=0)
# Evaluating model
tcc_utils.evaluate_model(deep_model, deep_history, x_train, y_train,
                         x_test, y_test, X, y_scaler)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 84)                4788
# _________________________________________________________________
# dense_5 (Dense)              (None, 84)                7140
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 85
# =================================================================
# Total params: 12,013
# Trainable params: 12,013
# Non-trainable params: 0
# _________________________________________________________________
# None
# MSE of training: 0.008130162361670624
# MSE of testing: 0.17361831665039062
#     Prediction      Real     % error
# 8     7.263714  8.491036   14.454322
# 0     6.697012  8.075241   17.067342
# 7     6.249869  5.156991   21.192180
# 9     3.850414  4.785659   19.542655
# 2     5.218067  4.616062   13.041525
# 1     4.260653  3.669486   16.110340
# 6     3.455554  3.491649    1.033757
# 3     2.676479  3.003443   10.886316
# 10    1.058336  1.377930   23.193793
# 5     2.488248  0.900556  176.301167
# 4    -1.048820  0.667981  257.013490
# count     11.000000
# mean      51.803353
# std       83.688097
# min        1.033757
# 25%       13.747923
# 50%       17.067342
# 75%       22.192986
# max      257.013490
# Name: % error, dtype: float64

# %% [markdown]
# ### 3) Linear
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>'linear'</font>, <font color=red>'linear'</font>, output(none)

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['linear', 'linear']
# Create model
deep_model = tcc_utils.deep_model(x_train, glorot_normal, layers, activations)
# Fit model
deep_history = deep_model.fit(x_train, y_train, epochs=40, verbose=0)
# Evaluating model
tcc_utils.evaluate_model(deep_model, deep_history, x_train, y_train,
                         x_test, y_test, X, y_scaler)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 84)                4788
# _________________________________________________________________
# dense_8 (Dense)              (None, 84)                7140
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 85
# =================================================================
# Total params: 12,013
# Trainable params: 12,013
# Non-trainable params: 0
# _________________________________________________________________
# None
# MSE of training: 0.025096097114411266
# MSE of testing: 0.19687123596668243
#     Prediction      Real     % error
# 8     6.710611  8.491036   20.968285
# 0     5.594120  8.075241   30.725039
# 7     5.835775  5.156991   13.162410
# 9     4.861237  4.785659    1.579255
# 2     4.267723  4.616062    7.546251
# 1     3.929130  3.669486    7.075758
# 6     3.550086  3.491649    1.673638
# 3     2.879733  3.003443    4.118958
# 10    0.633097  1.377930   54.054539
# 5     2.418606  0.900556  168.567967
# 4    -0.103628  0.667981  115.513589
# count     11.000000
# mean      38.635063
# std       54.724138
# min        1.579255
# 25%        5.597358
# 50%       13.162410
# 75%       42.389789
# max      168.567967
# Name: % error, dtype: float64

# %% [markdown]
# ### 4) softmax
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>'softmax'</font>, <font color=red>'softmax'</font>, output(none)

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['softmax', 'softmax']
# Create model
deep_model = tcc_utils.deep_model(x_train, glorot_normal, layers, activations)
# Fit model
deep_history = deep_model.fit(x_train, y_train, epochs=40, verbose=0)
# Evaluating model
tcc_utils.evaluate_model(deep_model, deep_history, x_train, y_train,
                         x_test, y_test, X, y_scaler)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 84)                4788
# _________________________________________________________________
# dense_11 (Dense)             (None, 84)                7140
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 85
# =================================================================
# Total params: 12,013
# Trainable params: 12,013
# Non-trainable params: 0
# _________________________________________________________________
# None
# MSE of training: 0.9702517336065118
# MSE of testing: 0.997279167175293
#     Prediction      Real     % error
# 8     3.642030  8.491036   57.107354
# 0     3.638525  8.075241   54.942208
# 7     3.645884  5.156991   29.302101
# 9     3.620495  4.785659   24.346992
# 2     3.639180  4.616062   21.162681
# 1     3.613451  3.669486    1.527043
# 6     3.631974  3.491649    4.018870
# 3     3.575702  3.003443   19.053417
# 10    3.549487  1.377930  157.595480
# 5     3.546924  0.900556  293.859220
# 4     3.547826  0.667981  431.126672
# count     11.000000
# mean      99.458367
# std      140.288563
# min        1.527043
# 25%       20.108049
# 50%       29.302101
# 75%      107.351417
# max      431.126672
# Name: % error, dtype: float64

# %% [markdown]
# ### 5) softplus
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>'softplus'</font>, <font color=red>'softplus'</font>, output(none)

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['softplus', 'softplus']
# Create model
deep_model = tcc_utils.deep_model(x_train, glorot_normal, layers, activations)
# Fit model
deep_history = deep_model.fit(x_train, y_train, epochs=40, verbose=0)
# Evaluating model
tcc_utils.evaluate_model(deep_model, deep_history, x_train, y_train,
                         x_test, y_test, X, y_scaler)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 84)                4788
# _________________________________________________________________
# dense_14 (Dense)             (None, 84)                7140
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 85
# =================================================================
# Total params: 12,013
# Trainable params: 12,013
# Non-trainable params: 0
# _________________________________________________________________
# None
# MSE of training: 0.024805954911492088
# MSE of testing: 0.12596391141414642
#     Prediction      Real    % error
# 8     6.947763  8.491036  18.175320
# 0     6.426902  8.075241  20.412253
# 7     6.152192  5.156991  19.298105
# 9     4.125566  4.785659  13.793154
# 2     4.940591  4.616062   7.030431
# 1     3.628992  3.669486   1.103535
# 6     4.021967  3.491649  15.188183
# 3     2.280879  3.003443  24.057852
# 10    0.722728  1.377930  47.549726
# 5     1.533159  0.900556  70.245780
# 4     0.081543  0.667981  87.792646
# count    11.000000
# mean     29.513362
# std      27.370325
# min       1.103535
# 25%      14.490668
# 50%      19.298105
# 75%      35.803789
# max      87.792646
# Name: % error, dtype: float64

# %% [markdown]
# ### 6) tanh
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>'tanh'</font>, <font color=red>'tanh'</font>, output(none)

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['tanh', 'tanh']
# Create model
deep_model = tcc_utils.deep_model(x_train, glorot_normal, layers, activations)
# Fit model
deep_history = deep_model.fit(x_train, y_train, epochs=40, verbose=0)
# Evaluating model
tcc_utils.evaluate_model(deep_model, deep_history, x_train, y_train,
                         x_test, y_test, X, y_scaler)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 84)                4788
# _________________________________________________________________
# dense_17 (Dense)             (None, 84)                7140
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 85
# =================================================================
# Total params: 12,013
# Trainable params: 12,013
# Non-trainable params: 0
# _________________________________________________________________
# None
# MSE of training: 0.010092409496957605
# MSE of testing: 0.13037997484207153
#     Prediction      Real     % error
# 8     6.736727  8.491036   20.660715
# 0     6.720533  8.075241   16.776070
# 7     6.004710  5.156991   16.438261
# 9     4.579584  4.785659    4.306098
# 2     4.811029  4.616062    4.223669
# 1     4.141287  3.669486   12.857413
# 6     4.109865  3.491649   17.705568
# 3     3.008649  3.003443    0.173340
# 10    1.470185  1.377930    6.695145
# 5     1.600694  0.900556   77.745065
# 4    -0.779390  0.667981  216.678428
# count     11.000000
# mean      35.841797
# std       63.562105
# min        0.173340
# 25%        5.500622
# 50%       16.438261
# 75%       19.183141
# max      216.678428
# Name: % error, dtype: float64

# %% [markdown]
# ### 7) sigmoid
#
# Using model specified above, in **A)** with:
#
# **activations:** input(none), <font color=red>'sigmoid'</font>, <font color=red>'sigmoid'</font>, output(none)

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['sigmoid', 'sigmoid']
# Create model
deep_model = tcc_utils.deep_model(x_train, glorot_normal, layers, activations)
# Fit model
deep_history = deep_model.fit(x_train, y_train, epochs=40, verbose=0)
# Evaluating model
tcc_utils.evaluate_model(deep_model, deep_history, x_train, y_train,
                         x_test, y_test, X, y_scaler)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 84)                4788
# _________________________________________________________________
# dense_20 (Dense)             (None, 84)                7140
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 85
# =================================================================
# Total params: 12,013
# Trainable params: 12,013
# Non-trainable params: 0
# _________________________________________________________________
# None
# MSE of training: 0.047402547164396805
# MSE of testing: 0.12414507567882538
#     Prediction      Real    % error
# 8     7.102388  8.491036  16.354283
# 0     6.673033  8.075241  17.364283
# 7     6.763009  5.156991  31.142551
# 9     4.061865  4.785659  15.124218
# 2     5.356738  4.616062  16.045610
# 1     3.567591  3.669486   2.776824
# 6     4.287808  3.491649  22.801820
# 3     2.617441  3.003443  12.851982
# 10    1.168710  1.377930  15.183684
# 5     1.024886  0.900556  13.805876
# 4     0.960312  0.667981  43.763350
# count    11.000000
# mean     18.837680
# std      10.727475
# min       2.776824
# 25%      14.465047
# 50%      16.045610
# 75%      20.083051
# max      43.763350
# Name: % error, dtype: float64
