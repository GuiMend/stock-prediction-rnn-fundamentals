# %%
import pandas as pd
import numpy as np
import tcc_utils

from keras.initializers import glorot_normal as gl_normal, glorot_uniform as gl_uni, RandomUniform as rnd_uni
# Out:
# Using TensorFlow backend.

# %%
import tratamento_dados_empresa

x_csv_path = '../data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = '../data/grendene-cotacao-raw.csv'

x_train, x_test, y_train, y_test, x_scaler, y_scaler = tratamento_dados_empresa.get_scaled_splits_and_scaler(
    x_csv_path, y_csv_path, 0.2, 0)

# %%
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
glorot_uniform = gl_uni(seed=0)
random_uniform = rnd_uni(minval=-0.05, maxval=0.05, seed=0)

# %%
linear_model = tcc_utils.linear_model(x_train, random_uniform)

# %%
linear_history = linear_model.fit(x_train, y_train, epochs=100, verbose=0)
tcc_utils.plot_loss(linear_history)

# %%
linear_history_with_val = linear_model.fit(x_train, y_train, validation_split=0.2, epochs=50, verbose=0)
tcc_utils.plot_loss_with_validation(linear_history_with_val)

# %%
# Evaluating model against Training and Test set
linr_train_eval = linear_model.evaluate(x_train, y_train, verbose=0)
linr_test_eval = linear_model.evaluate(x_test, y_test, verbose=0)
print(f'MSE of training set using Linear model: {linr_train_eval}')
print(f'MSE of testing set using Linear model: {linr_test_eval}')
# Out:
# MSE of training set using Linear model: 0.029790099371563305
# MSE of testing set using Linear model: 0.14062665402889252

# %%
X = tratamento_dados_empresa.treat_economatica_indicadores_financeiros(x_csv_path)
tcc_utils.linear_model_weighs_table(linear_model, X)

# %%
prediction_results = tcc_utils.prediction_results_data_frame(x_test, y_test, linear_model, y_scaler)
print(prediction_results)
# Out:
#     Prediction      Real     % error
# 0     6.645180  8.075241   17.709202
# 1     4.236459  3.669486   15.451017
# 2     5.058396  4.616062    9.582498
# 3     2.421391  3.003443   19.379504
# 4     1.570627  0.667981  135.130483
# 5     0.953269  0.900556    5.853353
# 6     5.002497  3.491649   43.270324
# 7     6.289382  5.156991   21.958384
# 8     7.004307  8.491036   17.509391
# 9     4.548274  4.785659    4.960346
# 10    1.623693  1.377930   17.835625

# %%
layers=[32, 16, 8]
activations=['relu', 'relu', 'relu']

deep_model = tcc_utils.deep_model(x_train, glorot_uniform, layers, activations)

# %%
deep_history = deep_model.fit(x_train, y_train, epochs=40, validation_split=0.2, verbose=0)
tcc_utils.plot_loss(deep_history)

# %%
# summarize layers
print(linear_model.summary())
print(deep_model.summary())
# plot graph
from keras.utils import plot_model
# plot_model(deep_model, to_file='multilayer_perceptron_graph.png')
plot_model(deep_model)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 1)                 57
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 32)                1824
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_7 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 2,497
# Trainable params: 2,497
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
prediction_results = tcc_utils.prediction_results_data_frame(x_test, y_test, linear_model, y_scaler)
prediction_results.sort_values('Real', ascending=True, inplace=True)
print(prediction_results)
import matplotlib.pyplot as plt

# %matplotlib inline
plt.plot(prediction_results['Real'], prediction_results['% error'], 'k',
        prediction_results['Real'], prediction_results['% error'], 'ro')
plt.yscale('linear')
plt.grid(True)
plt.show()
# Out:
#     Prediction      Real     % error
# 4     1.570627  0.667981  135.130483
# 5     0.953269  0.900556    5.853353
# 10    1.623693  1.377930   17.835625
# 3     2.421391  3.003443   19.379504
# 6     5.002497  3.491649   43.270324
# 1     4.236459  3.669486   15.451017
# 2     5.058396  4.616062    9.582498
# 9     4.548274  4.785659    4.960346
# 7     6.289382  5.156991   21.958384
# 0     6.645180  8.075241   17.709202
# 8     7.004307  8.491036   17.509391

# %%
prediction_results = tcc_utils.prediction_results_data_frame(x_test, y_test, deep_model, y_scaler)
prediction_results.sort_values('Real', ascending=True, inplace=True)
print(prediction_results)
plt.plot(prediction_results['Real'], prediction_results['% error'], 'ro')
plt.plot(prediction_results['Real'], prediction_results['% error'], 'ro',
        prediction_results['Real'], prediction_results['% error'], 'k')
#plt.yscale('log')
plt.grid(True)
plt.show()
#plt.scatter('a', 'b', c='c', s='d', data=data)
# Out:
#     Prediction      Real    % error
# 4     1.067951  0.667981  59.877378
# 5     0.971516  0.900556   7.879586
# 10    1.901559  1.377930  38.001049
# 3     2.835420  3.003443   5.594347
# 6     4.752436  3.491649  36.108649
# 1     3.737392  3.669486   1.850567
# 2     3.237335  4.616062  29.868029
# 9     5.243757  4.785659   9.572307
# 7     5.623794  5.156991   9.051848
# 0     6.965249  8.075241  13.745625
# 8     7.507805  8.491036  11.579631

# %%
tcc_utils.plot_compare_histories([linear_history, deep_history])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-f411c3dca64b> in <module>
# ----> 1 tcc_utils.plot_compare_histories([linear_history, deep_history])
#
# AttributeError: module 'tcc_utils' has no attribute 'plot_compare_histories'

# %%
import numpy as np
import tcc_utils
import tratamento_dados_empresa
from sklearn.preprocessing import StandardScaler
from keras.initializers import glorot_normal as gl_normal

x_csv_path = '../data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = '../data/grendene-cotacao-raw.csv'

x, y = tratamento_dados_empresa.get_x_y(x_csv_path, y_csv_path)
x_int_index = x.reset_index()

number_hidden_layer = round(x.shape[1]*1.5)

# Feature Scaling X
x_scaler = StandardScaler()
x = x_scaler.fit_transform(x)
# Feature Scaling y
y_scaler = StandardScaler()
y = y_scaler.fit_transform(y)
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['relu', 'relu']
# Create model
deep_model = tcc_utils.deep_model(x, glorot_normal, layers, activations)


results = np.array([])

for i in range(x.shape[0]):
    x_train = np.delete(x, i, 0)
    y_train = np.delete(y, i, 0)
    x_test = x[i:i+1]
    y_test = y[i:i+1]
    deep_model.train_on_batch(x_train, y_train)
    predictions_real = y_scaler.inverse_transform(deep_model.predict(x_test))
    y_real = y_scaler.inverse_transform(y_test)
    results = np.append([results], [[tcc_utils.calculate_diff_percent(predictions_real[0,0], y_real[0,0])]])
    print(f'R$ {predictions_real[0,0]} - R$ {y_real[0,0]} - error: {tcc_utils.calculate_diff_percent(predictions_real[0,0], y_real[0,0])}')
# Out:
# R$ 3.4289333820343018 - R$ 1.026738689 - error: 233.96358964265167
# R$ 1.8961750268936157 - R$ 0.8603665941999998 - error: 120.39152143706234
# R$ 2.6734678745269775 - R$ 0.9005563231 - error: 196.8684807324493
# R$ -0.46146509051322937 - R$ 1.1752936440000004 - error: 139.26381231354887
# R$ 0.1291203647851944 - R$ 1.3779304800000003 - error: 90.62939918527715
# R$ -1.3360106945037842 - R$ 1.311384023 - error: 201.87791455987443
# R$ -1.5317614078521729 - R$ 1.3161578840000003 - error: 216.38128118770382
# R$ -0.4739319980144501 - R$ 1.3062001300000001 - error: 136.28326066806088
# R$ 0.6647961139678955 - R$ 1.1562058570000002 - error: 42.50192472706914
# R$ -0.449602335691452 - R$ 1.0377015510000005 - error: 143.32674797085772
# R$ 0.827307939529419 - R$ 0.9181082562000005 - error: 9.889935751846851
# R$ 0.017070075497031212 - R$ 0.6679810606999999 - error: 97.4445270230951
# R$ 1.037588119506836 - R$ 0.7225226334999997 - error: 43.606313684682156
# R$ 1.0212650299072266 - R$ 1.0148586869999994 - error: 0.6312546750882959
# R$ 1.2522199153900146 - R$ 1.6110844600000003 - error: 22.274719514704124
# R$ 1.64107084274292 - R$ 1.7570071459999999 - error: 6.598510627632925
# R$ 2.01090931892395 - R$ 1.835973759 - error: 9.528216787762387
# R$ 1.687991738319397 - R$ 1.503906074 - error: 12.240502748271824
# R$ 1.822473406791687 - R$ 1.51175937 - error: 20.553141125342385
# R$ 2.424265146255493 - R$ 1.9551388200000002 - error: 23.994527726450286
# R$ 1.5937893390655518 - R$ 1.9345584119999997 - error: 17.61482469697834
# R$ 1.8743375539779663 - R$ 1.898384281 - error: 1.2666943812538711
# R$ 1.8899198770523071 - R$ 1.598303868 - error: 18.24534213367162
# R$ 2.3557631969451904 - R$ 1.798002499 - error: 31.021130296281658
# R$ 1.9403009414672852 - R$ 2.012524323 - error: 3.588696082194625
# R$ 2.343951463699341 - R$ 2.388120727 - error: 1.849540636756057
# R$ 3.342724561691284 - R$ 3.003443167 - error: 11.29641467563299
# R$ 3.6373355388641357 - R$ 3.6017053889999997 - error: 0.9892577547556887
# R$ 4.359639644622803 - R$ 4.564561296 - error: 4.4894051824164
# R$ 4.758938789367676 - R$ 4.900165596 - error: 2.88208232692396
# R$ 4.854644298553467 - R$ 4.785658811 - error: 1.4415045091576746
# R$ 4.2927327156066895 - R$ 4.57179931 - error: 6.104086716643535
# R$ 3.2044246196746826 - R$ 3.491648923 - error: 8.226036169711367
# R$ 3.4883596897125244 - R$ 3.669485885 - error: 4.936010137765537
# R$ 4.053725242614746 - R$ 4.297708183 - error: 5.67704762622907
# R$ 4.571162700653076 - R$ 4.505757423 - error: 1.4515934062319757
# R$ 4.373807907104492 - R$ 4.3281775719999995 - error: 1.0542620848018354
# R$ 5.069828987121582 - R$ 4.7944934230000005 - error: 5.7427456840539195
# R$ 4.803213596343994 - R$ 4.49219144 - error: 6.923617581711836
# R$ 4.7502760887146 - R$ 4.749780418 - error: 0.010435655356212043
# R$ 4.872217655181885 - R$ 4.61606226 - error: 5.549218809320937
# R$ 4.884843349456787 - R$ 4.764058747 - error: 2.5353298284335186
# R$ 5.065920352935791 - R$ 5.281611648999999 - error: 4.083815895571317
# R$ 5.152745246887207 - R$ 5.156990634 - error: 0.08232295565562477
# R$ 6.03592586517334 - R$ 5.928322757 - error: 1.8150683183752934
# R$ 7.962385654449463 - R$ 8.075240928 - error: 1.3975468293363669
# R$ 8.190108299255371 - R$ 8.491035952999999 - error: 3.544062884792121
# R$ 8.284952163696289 - R$ 8.1060925 - error: 2.20648436588021
# R$ 8.800440788269043 - R$ 8.770984718 - error: 0.33583538469281854
# R$ 7.771117687225342 - R$ 7.693246559 - error: 1.0122011250795462
# R$ 7.101823329925537 - R$ 6.9176102760000004 - error: 2.6629579663463634
# R$ 7.654630661010742 - R$ 7.666290503000001 - error: 0.15209235789715836
# R$ 8.481172561645508 - R$ 8.434865313 - error: 0.5489980803147921
# R$ 7.206620693206787 - R$ 7.084401446 - error: 1.725188050654504
# R$ 8.10588264465332 - R$ 7.93 - error: 2.2179400334592763

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.plot(y_scaler.inverse_transform(y),results, 'ro')
plt.show()

results_df = pd.DataFrame(results)
plt.figure(figsize=(12, 6))
plt.boxplot(results_df.iloc[:,0], vert=False)
plt.title(f'Error - Median: {results_df.iloc[:,0].median()}%')
plt.show()
results_df.describe()
# Out:
#                 0
# count   55.000000
# mean    35.144170
# std     62.592106
# min      0.010436
# 25%      1.770128
# 50%      5.677048
# 75%     23.134624
# max    233.963590

# %%
import numpy as np
import tcc_utils
import tratamento_dados_empresa
from sklearn.preprocessing import StandardScaler
from keras.initializers import glorot_normal as gl_normal

x_csv_path = '../data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = '../data/grendene-cotacao-raw.csv'

x, y = tratamento_dados_empresa.get_x_y(x_csv_path, y_csv_path)
x_int_index = x.reset_index()

x_train, x_test, y_train, y_test, x_scaler, y_scaler = tratamento_dados_empresa.get_scaled_splits_and_scaler(
    x_csv_path, y_csv_path, 0.1, 0)

number_hidden_layer = round(x.shape[1]*1.5)

# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['relu', 'relu']
# Create model
deep_model = tcc_utils.deep_model(x, glorot_normal, layers, activations)


results = np.array([])

for i in range(x_train.shape[0]):
    x_train1 = np.delete(x_train, i, 0)
    y_train1 = np.delete(y_train, i, 0)
    x_test1 = x_train[i:i+1]
    y_test1 = y_train[i:i+1]
    deep_model.train_on_batch(x_train1, y_train1)
    predictions_real = y_scaler.inverse_transform(deep_model.predict(x_test1))
    y_real = y_scaler.inverse_transform(y_test1)
    results = np.append([results], [[tcc_utils.calculate_diff_percent(predictions_real[0,0], y_real[0,0])]])
    print(f'R$ {predictions_real[0,0]} - R$ {y_real[0,0]} - error: {tcc_utils.calculate_diff_percent(predictions_real[0,0], y_real[0,0])}')
# Out:
# R$ 4.817890644073486 - R$ 3.491648923 - error: 37.98324947096882
# R$ 6.009188175201416 - R$ 5.156990634 - error: 16.52509383249379
# R$ 6.665177345275879 - R$ 8.491035952999999 - error: 21.503366819204427
# R$ 3.672144651412964 - R$ 4.785658811 - error: 23.267729764344796
# R$ 0.05086049064993858 - R$ 1.3779304799999998 - error: 96.30892186593198
# R$ 0.23776468634605408 - R$ 0.9181082562 - error: 74.10276133120193
# R$ 5.295533657073975 - R$ 4.564561296 - error: 16.014077009208698
# R$ 2.020409107208252 - R$ 1.5983038680000003 - error: 26.409573777509717
# R$ 4.1110429763793945 - R$ 4.57179931 - error: 10.078227463151826
# R$ 7.8505473136901855 - R$ 7.693246558999999 - error: 2.044660254729087
# R$ 3.8962039947509766 - R$ 4.7944934230000005 - error: 18.735856929947523
# R$ 0.7263630032539368 - R$ 1.3062001299999997 - error: 44.39113987425978
# R$ 1.2718974351882935 - R$ 1.6110844599999998 - error: 21.053336012669778
# R$ 2.7986865043640137 - R$ 3.6017053889999997 - error: 22.29551831442108
# R$ 4.959798812866211 - R$ 4.505757423 - error: 10.076915981950556
# R$ 7.439779758453369 - R$ 6.9176102760000004 - error: 7.54840850553531
# R$ 1.554735541343689 - R$ 1.51175937 - error: 2.8427917958721776
# R$ 8.342314720153809 - R$ 8.434865313 - error: 1.0972385380422132
# R$ 4.99821138381958 - R$ 4.297708183 - error: 16.299459409330954
# R$ 1.4901384115219116 - R$ 1.7570071459999999 - error: 15.188824649099534
# R$ 1.351366400718689 - R$ 1.311384023 - error: 3.048868753732632
# R$ 4.747100830078125 - R$ 4.900165596 - error: 3.1236651685163763
# R$ 1.762542963027954 - R$ 1.835973759 - error: 3.9995558548746084
# R$ 6.850944519042969 - R$ 7.084401446 - error: 3.295365582209434
# R$ 1.554341435432434 - R$ 1.934558412 - error: 19.65394139608775
# R$ 8.498138427734375 - R$ 8.770984718000001 - error: 3.11078287145667
# R$ 1.0108870267868042 - R$ 1.1562058569999998 - error: 12.568594885884202
# R$ 0.9494965672492981 - R$ 1.0148586870000003 - error: 6.440514387664905
# R$ 2.3713467121124268 - R$ 2.388120727 - error: 0.7023939241398847
# R$ 1.3382352590560913 - R$ 1.503906074 - error: 11.016034698448113
# R$ 4.675414562225342 - R$ 4.764058747 - error: 1.8606862232855288
# R$ 8.202757835388184 - R$ 7.93 - error: 3.4395691726126594
# R$ 4.948791027069092 - R$ 4.49219144 - error: 10.164294936395049
# R$ 0.5195687413215637 - R$ 0.8603665942000003 - error: 39.61077233540461
# R$ 0.9793470501899719 - R$ 0.7225226334999997 - error: 35.54551854602522
# R$ 5.164841175079346 - R$ 5.281611648999999 - error: 2.2108871624963666
# R$ 2.167780637741089 - R$ 2.012524323 - error: 7.714506253005361
# R$ 1.5115796327590942 - R$ 1.316157884 - error: 14.847895616077498
# R$ 2.199950933456421 - R$ 1.798002499 - error: 22.355276740714963
# R$ 4.505147933959961 - R$ 4.3281775719999995 - error: 4.088796243130697
# R$ 1.9691450595855713 - R$ 1.8983842809999998 - error: 3.727421223078043
# R$ 2.0998659133911133 - R$ 1.95513882 - error: 7.402394751238857
# R$ 1.1231132745742798 - R$ 1.0377015509999996 - error: 8.230856308538003
# R$ 4.714791774749756 - R$ 4.749780418 - error: 0.7366370688979589
# R$ 7.603868007659912 - R$ 7.666290503 - error: 0.8142464118162548
# R$ 1.3463209867477417 - R$ 1.175293644 - error: 14.551881874019715
# R$ 0.9291897416114807 - R$ 1.0267386890000005 - error: 9.500854349175087
# R$ 8.327254295349121 - R$ 8.1060925 - error: 2.7283403853227712
# R$ 5.99472188949585 - R$ 5.928322757 - error: 1.1200323467113398

# %%
plt.plot(y_scaler.inverse_transform(y_train),results, 'ro')
plt.show()

# %%
prediction_results = tcc_utils.prediction_results_data_frame(x_test, y_test, deep_model, y_scaler)
prediction_results.sort_values(by='Real', ascending=False, inplace=True)
# Print and plot results
print(prediction_results)
# Out:
#    Prediction      Real     % error
# 0    7.143155  8.075241   11.542520
# 2    5.261053  4.616062   13.972750
# 1    2.972247  3.669486   19.001000
# 3    2.884259  3.003443    3.968260
# 5    2.325243  0.900556  158.200756
# 4   -0.605276  0.667981  190.612792

# %%
import numpy as np
import tcc_utils
import tratamento_dados_empresa
from sklearn.preprocessing import StandardScaler
from keras.initializers import glorot_normal as gl_normal

x_csv_path = '../data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = '../data/grendene-cotacao-raw.csv'

x, y = tratamento_dados_empresa.get_x_y(x_csv_path, y_csv_path)
x_int_index = x.reset_index()

number_hidden_layer = round(x.shape[1]*1.5)

last_3_x = x.iloc[x.shape[0] - 3:, :]
last_3_y = y.iloc[y.shape[0] - 3:, :]
x = x.iloc[:x.shape[0] - 3,:]
y = y.iloc[:y.shape[0] - 3,:]

# Feature Scaling X
x_scaler = StandardScaler()
x = x_scaler.fit_transform(x)
last_3_x = x_scaler.transform(last_3_x)
# Feature Scaling y
y_scaler = StandardScaler()
y = y_scaler.fit_transform(y)
last_3_y = y_scaler.transform(last_3_y)
# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)
# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['relu', 'relu']
# Create model
deep_model = tcc_utils.deep_model(x, glorot_normal, layers, activations)


results = np.array([])

for i in range(x.shape[0]):
    x_train = np.delete(x, i, 0)
    y_train = np.delete(y, i, 0)
    x_test = x[i:i+1]
    y_test = y[i:i+1]
    deep_model.train_on_batch(x_train, y_train)
    predictions_real = y_scaler.inverse_transform(deep_model.predict(x_test))
    y_real = y_scaler.inverse_transform(y_test)
    results = np.append([results], [[tcc_utils.calculate_diff_percent(predictions_real[0,0], y_real[0,0])]])
    print(f'R$ {predictions_real[0,0]} - R$ {y_real[0,0]} - error: {tcc_utils.calculate_diff_percent(predictions_real[0,0], y_real[0,0])}')
# Out:
# R$ 3.4666335582733154 - R$ 1.026738689 - error: 237.63542714550567
# R$ 2.118772029876709 - R$ 0.8603665941999998 - error: 146.2638652128074
# R$ 2.8023290634155273 - R$ 0.9005563231000004 - error: 211.17754564967376
# R$ -0.26800259947776794 - R$ 1.1752936440000004 - error: 122.80303316928071
# R$ 0.3098582327365875 - R$ 1.3779304800000003 - error: 77.51278186860432
# R$ -1.129343867301941 - R$ 1.311384023 - error: 186.11847082888707
# R$ -1.4001449346542358 - R$ 1.3161578840000003 - error: 206.3812291576286
# R$ -0.37025341391563416 - R$ 1.3062001300000001 - error: 128.3458411473006
# R$ 0.63782799243927 - R$ 1.1562058570000002 - error: 44.83439185352009
# R$ -0.35249218344688416 - R$ 1.037701551 - error: 133.9685512763471
# R$ 0.7718356847763062 - R$ 0.9181082562 - error: 15.931952516047298
# R$ -0.10101232677698135 - R$ 0.6679810606999999 - error: 115.12203454857345
# R$ 1.0032976865768433 - R$ 0.7225226335000001 - error: 38.86038167645071
# R$ 1.0449601411819458 - R$ 1.0148586870000003 - error: 2.966073461018276
# R$ 1.2559715509414673 - R$ 1.61108446 - error: 22.041855524975567
# R$ 1.5414704084396362 - R$ 1.7570071459999999 - error: 12.267265847555274
# R$ 1.944671630859375 - R$ 1.835973759 - error: 5.920448008939924
# R$ 1.6147832870483398 - R$ 1.503906074 - error: 7.372615548618347
# R$ 1.8423835039138794 - R$ 1.5117593699999998 - error: 21.870156089317284
# R$ 2.5175681114196777 - R$ 1.95513882 - error: 28.766719051677253
# R$ 1.5720393657684326 - R$ 1.934558412 - error: 18.73911089904931
# R$ 1.97153639793396 - R$ 1.898384281 - error: 3.8533882557975074
# R$ 1.8995943069458008 - R$ 1.5983038680000001 - error: 18.85063566309286
# R$ 2.3203375339508057 - R$ 1.798002499 - error: 29.0508514443842
# R$ 1.7817409038543701 - R$ 2.012524323 - error: 11.467360493890038
# R$ 2.3226327896118164 - R$ 2.388120727 - error: 2.7422373018155874
# R$ 3.2593765258789062 - R$ 3.003443167 - error: 8.521331839767965
# R$ 3.6272521018981934 - R$ 3.6017053889999997 - error: 0.7092949072463312
# R$ 4.386982440948486 - R$ 4.564561296 - error: 3.890381649757423
# R$ 4.731857776641846 - R$ 4.900165596 - error: 3.434737378988655
# R$ 4.753059387207031 - R$ 4.785658811 - error: 0.6811898858739803
# R$ 4.296563625335693 - R$ 4.57179931 - error: 6.020292361965183
# R$ 3.1828501224517822 - R$ 3.491648923 - error: 8.843924671639098
# R$ 3.4423747062683105 - R$ 3.669485885 - error: 6.189182513552285
# R$ 3.985332727432251 - R$ 4.297708183 - error: 7.268419405565516
# R$ 4.582019805908203 - R$ 4.505757423 - error: 1.6925541201777818
# R$ 4.360217571258545 - R$ 4.3281775719999995 - error: 0.740265359393286
# R$ 5.09633207321167 - R$ 4.7944934230000005 - error: 6.295527464146642
# R$ 4.7491936683654785 - R$ 4.49219144 - error: 5.721088065772158
# R$ 4.822335720062256 - R$ 4.749780418 - error: 1.5275506587061678
# R$ 4.891963481903076 - R$ 4.61606226 - error: 5.976982249435183
# R$ 4.802779197692871 - R$ 4.764058747 - error: 0.8127618224114882
# R$ 5.047491550445557 - R$ 5.281611648999999 - error: 4.432739741453163
# R$ 5.113852500915527 - R$ 5.156990634 - error: 0.8364981855903102
# R$ 5.980830669403076 - R$ 5.928322757 - error: 0.8857127817657392
# R$ 7.891457557678223 - R$ 8.075240928 - error: 2.2758871464073405
# R$ 8.224536895751953 - R$ 8.491035952999999 - error: 3.138592967020569
# R$ 8.399808883666992 - R$ 8.1060925 - error: 3.623402812970508
# R$ 8.85392951965332 - R$ 8.770984718 - error: 0.9456726276480667
# R$ 7.82983922958374 - R$ 7.6932465589999985 - error: 1.7754880145359153
# R$ 7.159155368804932 - R$ 6.9176102760000004 - error: 3.4917418467899126
# R$ 7.721393585205078 - R$ 7.666290502999999 - error: 0.7187711212289172

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.plot(y_scaler.inverse_transform(y),results, 'ro')
plt.show()

results_df = pd.DataFrame(results)
plt.figure(figsize=(12, 6))
plt.boxplot(results_df.iloc[:,0], vert=False)
plt.title(f'Error - Median: {results_df.iloc[:,0].median()}%')
plt.show()
results_df.describe()
# Out:
#                 0
# count   52.000000
# mean    37.332966
# std     63.243304
# min      0.681190
# 25%      2.910114
# 50%      6.242355
# 75%     28.837752
# max    237.635427

# %%
prediction_results = tcc_utils.prediction_results_data_frame(last_3_x, last_3_y, deep_model, y_scaler)
sorted_pred = prediction_results.sort_values(by='Real', ascending=False)
# Print and plot results
print(sorted_pred)
plt.plot(sorted_pred['Real'], sorted_pred['% error'], 'k',
             sorted_pred['Real'], sorted_pred['% error'], 'ro')
plt.grid(True)
plt.title(f'Error - Mean: {sorted_pred["% error"].mean()}% / '
              f'Std: {sorted_pred["% error"].std()}%')
plt.xlabel('Stock price')
plt.ylabel('Error (%)')
plt.show()
plt.figure(figsize=(12, 6))
plt.boxplot(prediction_results["% error"], vert=False)
plt.title(f'Error - Median: {sorted_pred["% error"].median()}%')
plt.show()
sorted_pred['% error'].describe()
# Out:
#    Prediction      Real   % error
# 0    7.977844  8.434865  5.418244
# 2    8.191524  7.930000  3.297901
# 1    7.133227  7.084401  0.689203
# count    3.000000
# mean     3.135116
# std      2.368719
# min      0.689203
# 25%      1.993552
# 50%      3.297901
# 75%      4.358072
# max      5.418244
# Name: % error, dtype: float64

# %%
prediction_results = tcc_utils.prediction_results_data_frame(last_3_x, last_3_y, deep_model, y_scaler)
sorted_pred = prediction_results.sort_values(by='Real', ascending=False)
# Print and plot results
print(prediction_results)
plt.plot(prediction_results.index, prediction_results['% error'], 'k',
             prediction_results.index, prediction_results['% error'], 'ro')
plt.grid(True)
plt.title(f'Error - Mean: {prediction_results["% error"].mean()}% / '
              f'Std: {prediction_results["% error"].std()}%')
plt.xlabel('Stock price')
plt.ylabel('Error (%)')
plt.show()
plt.figure(figsize=(12, 6))
plt.boxplot(prediction_results["% error"], vert=False)
plt.title(f'Error - Median: {prediction_results["% error"].median()}%')
plt.show()
prediction_results['% error'].describe()
# Out:
#    Prediction      Real   % error
# 0    7.977844  8.434865  5.418244
# 1    7.133227  7.084401  0.689203
# 2    8.191524  7.930000  3.297901
# count    3.000000
# mean     3.135116
# std      2.368719
# min      0.689203
# 25%      1.993552
# 50%      3.297901
# 75%      4.358072
# max      5.418244
# Name: % error, dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
import tcc_utils
import tratamento_dados_empresa
from sklearn.preprocessing import StandardScaler
from keras.initializers import glorot_normal as gl_normal
from sklearn.model_selection import KFold

x_csv_path = '../data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = '../data/grendene-cotacao-raw.csv'

x, y = tratamento_dados_empresa.get_x_y(x_csv_path, y_csv_path)


# Feature Scaling X
x_scaler = StandardScaler()
x = x_scaler.fit_transform(x)

# Feature Scaling y
y_scaler = StandardScaler()
y = y_scaler.fit_transform(y)

# Generate hidden layer # of nodes
number_hidden_layer = round(x.shape[1]*1.5)

# LOOCV: k-fold cross validation (folds=x.shape[0], shuffle=True, seed=1)
kfold = KFold(x.shape[0], True, 1)

# Keras Initializer with seed
glorot_normal = gl_normal(seed=0)

# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['relu', 'relu']

# Create model
deep_model = tcc_utils.deep_model(x, glorot_normal, layers, activations)

i = 0
results_loss = np.array([])
results_val_loss = np.array([])

for train, test in kfold.split(x):
#    print(f'Fold: {i}')
    i += 1
    deep_history = deep_model.fit(x[train,:], y[train,:], validation_data=(x[test,:], y[test,:]), batch_size=4, epochs=10, verbose=0)
    results_loss = np.append([results_loss], [[deep_history.history["loss"][-1]]])
    results_val_loss = np.append([results_val_loss], [[deep_history.history["val_loss"][-1]]])

# %%
plt.figure(figsize=(16, 8))
plt.plot(range(len(results_loss)), results_loss, 'k')
plt.plot(range(len(results_loss)), results_loss, 'ko')
plt.plot(range(len(results_val_loss)), results_val_loss, 'r')
plt.plot(range(len(results_val_loss)), results_val_loss, 'ro')
plt.legend(['loss', '', 'val_loss', ''], fontsize=20)
plt.xlabel('Fold #', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.title(f'loss: {results_loss[-1]} / val_loss: {results_val_loss[-1]}', fontsize=20)
plt.yscale('log')
plt.grid(True)
plt.show()

plt.figure(figsize=(16, 8))
plt.plot(range(len(results_loss)), results_loss, 'k')
plt.plot(range(len(results_loss)), results_loss, 'ko')
plt.plot(range(len(results_val_loss)), results_val_loss, 'r')
plt.plot(range(len(results_val_loss)), results_val_loss, 'ro')
plt.legend(['loss', '', 'val_loss', ''], fontsize=20)
plt.xlabel('Fold #', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.title(f'loss: {results_loss[-1]} / val_loss: {results_val_loss[-1]}', fontsize=20)
plt.grid(True)
plt.show()

print(f'Stats: Mean (std)')
print(f'loss: {results_loss.mean()} ({results_loss.std()})')
print(f'val_loss: {results_val_loss.mean()} ({results_val_loss.std()})')
# Out:
# Stats: Mean (std)
# loss: 0.003576465195590146 (0.008871254564466689)
# val_loss: 0.00312589434953762 (0.008070974524595553)

# %%
deep_history.history
# Out:
# {'val_loss': [0.001240336918272078,
#   0.0013646325096488,
#   1.057724603015231e-05,
#   0.0016966847470030189,
#   0.0005060465191490948,
#   0.0035307600628584623,
#   0.00299558462575078,
#   0.00012874417006969452,
#   0.006589366123080254,
#   0.00013276530080474913],
#  'loss': [0.0032125126648073397,
#   0.0032377811752397705,
#   0.003230807535281336,
#   0.0069922091810170695,
#   0.002019516191298694,
#   0.0023286973214622034,
#   0.003127503859879518,
#   0.006051256383350982,
#   0.008850798817110006,
#   0.004995941654434083]}

# %%
tcc_utils.plot_loss_with_validation(deep_history)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py:1001: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)

# %%
import matplotlib.pyplot as plt
import numpy as np
import tcc_utils
import tratamento_dados_empresa
from sklearn.preprocessing import StandardScaler
from keras.initializers import glorot_normal as gl_normal
from sklearn.model_selection import KFold

x_csv_path = '../data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = '../data/grendene-cotacao-raw.csv'

x, y = tratamento_dados_empresa.get_x_y(x_csv_path, y_csv_path)


# Feature Scaling X
x_scaler = StandardScaler()
x = x_scaler.fit_transform(x)

# Feature Scaling y
y_scaler = StandardScaler()
y = y_scaler.fit_transform(y)

# Generate hidden layer # of nodes
number_hidden_layer = round(x.shape[1]*1.5)

# LOOCV: k-fold cross validation (folds=x.shape[0], shuffle=True, seed=1)
kfold = KFold(x.shape[0], True, 1)

# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['relu', 'relu']

i = 0
results_loss = np.array([])
results_val_loss = np.array([])

for train, test in kfold.split(x):
    print(f'Fold: {i}')
    i += 1
    glorot_normal = gl_normal(seed=0)
    deep_model = tcc_utils.deep_model(x, glorot_normal, layers, activations)
    deep_history = deep_model.fit(x[train,:], y[train,:], validation_data=(x[test,:], y[test,:]), batch_size=4, epochs=10, verbose=1)
    results_loss = np.append([results_loss], [[deep_history.history["loss"][-1]]])
    results_val_loss = np.append([results_val_loss], [[deep_history.history["val_loss"][-1]]])
    print('')
# Out:
# Fold: 0
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 50ms/step - loss: 0.3593 - val_loss: 0.2403
# Epoch 2/10
# 54/54 [==============================] - 0s 805us/step - loss: 0.1368 - val_loss: 0.0357
# Epoch 3/10
# 54/54 [==============================] - 0s 699us/step - loss: 0.0508 - val_loss: 0.0015
# Epoch 4/10
# 54/54 [==============================] - 0s 905us/step - loss: 0.0270 - val_loss: 0.0344
# Epoch 5/10
# 54/54 [==============================] - 0s 726us/step - loss: 0.0122 - val_loss: 0.0174
# Epoch 6/10
# 54/54 [==============================] - 0s 778us/step - loss: 0.0067 - val_loss: 0.0156
# Epoch 7/10
# 54/54 [==============================] - 0s 739us/step - loss: 0.0049 - val_loss: 0.0269
# Epoch 8/10
# 54/54 [==============================] - 0s 769us/step - loss: 0.0032 - val_loss: 0.0079
# Epoch 9/10
# 54/54 [==============================] - 0s 890us/step - loss: 0.0025 - val_loss: 0.0126
# Epoch 10/10
# 54/54 [==============================] - 0s 745us/step - loss: 0.0020 - val_loss: 0.0150
#
# Fold: 1
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 48ms/step - loss: 0.4357 - val_loss: 0.0121
# Epoch 2/10
# 54/54 [==============================] - 0s 863us/step - loss: 0.1643 - val_loss: 1.3879
# Epoch 3/10
# 54/54 [==============================] - 0s 896us/step - loss: 0.0392 - val_loss: 0.4396
# Epoch 4/10
# 54/54 [==============================] - 0s 740us/step - loss: 0.0296 - val_loss: 0.7170
# Epoch 5/10
# 54/54 [==============================] - 0s 731us/step - loss: 0.0125 - val_loss: 0.6460
# Epoch 6/10
# 54/54 [==============================] - 0s 668us/step - loss: 0.0099 - val_loss: 0.5756
# Epoch 7/10
# 54/54 [==============================] - 0s 736us/step - loss: 0.0113 - val_loss: 0.5255
# Epoch 8/10
# 54/54 [==============================] - 0s 719us/step - loss: 0.0094 - val_loss: 0.5464
# Epoch 9/10
# 54/54 [==============================] - 0s 806us/step - loss: 0.0028 - val_loss: 0.5756
# Epoch 10/10
# 54/54 [==============================] - 0s 784us/step - loss: 0.0046 - val_loss: 0.5901
#
# Fold: 2
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 47ms/step - loss: 0.4631 - val_loss: 0.0716
# Epoch 2/10
# 54/54 [==============================] - 0s 809us/step - loss: 0.2384 - val_loss: 0.1061
# Epoch 3/10
# 54/54 [==============================] - 0s 780us/step - loss: 0.0729 - val_loss: 0.0383
# Epoch 4/10
# 54/54 [==============================] - 0s 721us/step - loss: 0.0345 - val_loss: 0.0126
# Epoch 5/10
# 54/54 [==============================] - 0s 866us/step - loss: 0.0232 - val_loss: 0.0052
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0154 - val_loss: 0.0523
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0071 - val_loss: 0.0058
# Epoch 8/10
# 54/54 [==============================] - 0s 816us/step - loss: 0.0039 - val_loss: 0.0070
# Epoch 9/10
# 54/54 [==============================] - 0s 771us/step - loss: 0.0032 - val_loss: 0.0064
# Epoch 10/10
# 54/54 [==============================] - 0s 790us/step - loss: 0.0018 - val_loss: 0.0120
#
# Fold: 3
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 50ms/step - loss: 0.3524 - val_loss: 0.5640
# Epoch 2/10
# 54/54 [==============================] - 0s 721us/step - loss: 0.1543 - val_loss: 0.0265
# Epoch 3/10
# 54/54 [==============================] - 0s 760us/step - loss: 0.0542 - val_loss: 0.0822
# Epoch 4/10
# 54/54 [==============================] - 0s 996us/step - loss: 0.0251 - val_loss: 0.0145
# Epoch 5/10
# 54/54 [==============================] - 0s 723us/step - loss: 0.0159 - val_loss: 0.0408
# Epoch 6/10
# 54/54 [==============================] - 0s 816us/step - loss: 0.0095 - val_loss: 0.0271
# Epoch 7/10
# 54/54 [==============================] - 0s 834us/step - loss: 0.0060 - val_loss: 0.0213
# Epoch 8/10
# 54/54 [==============================] - 0s 848us/step - loss: 0.0034 - val_loss: 0.1227
# Epoch 9/10
# 54/54 [==============================] - 0s 760us/step - loss: 0.0031 - val_loss: 0.0613
# Epoch 10/10
# 54/54 [==============================] - 0s 755us/step - loss: 0.0026 - val_loss: 0.0591
#
# Fold: 4
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 48ms/step - loss: 0.4776 - val_loss: 0.0793
# Epoch 2/10
# 54/54 [==============================] - 0s 677us/step - loss: 0.1578 - val_loss: 0.0132
# Epoch 3/10
# 54/54 [==============================] - 0s 803us/step - loss: 0.0597 - val_loss: 0.1251
# Epoch 4/10
# 54/54 [==============================] - 0s 684us/step - loss: 0.0305 - val_loss: 0.0418
# Epoch 5/10
# 54/54 [==============================] - 0s 863us/step - loss: 0.0243 - val_loss: 0.0259
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0149 - val_loss: 0.0705
# Epoch 7/10
# 54/54 [==============================] - 0s 978us/step - loss: 0.0097 - val_loss: 0.0486
# Epoch 8/10
# 54/54 [==============================] - 0s 825us/step - loss: 0.0084 - val_loss: 0.0384
# Epoch 9/10
# 54/54 [==============================] - 0s 880us/step - loss: 0.0042 - val_loss: 0.0366
# Epoch 10/10
# 54/54 [==============================] - 0s 818us/step - loss: 0.0064 - val_loss: 0.0503
#
# Fold: 5
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 52ms/step - loss: 0.4730 - val_loss: 0.0467
# Epoch 2/10
# 54/54 [==============================] - 0s 745us/step - loss: 0.1136 - val_loss: 5.5481e-05
# Epoch 3/10
# 54/54 [==============================] - 0s 891us/step - loss: 0.0753 - val_loss: 0.0227
# Epoch 4/10
# 54/54 [==============================] - 0s 841us/step - loss: 0.0400 - val_loss: 0.0301
# Epoch 5/10
# 54/54 [==============================] - 0s 823us/step - loss: 0.0196 - val_loss: 0.0037
# Epoch 6/10
# 54/54 [==============================] - 0s 760us/step - loss: 0.0102 - val_loss: 0.0216
# Epoch 7/10
# 54/54 [==============================] - 0s 845us/step - loss: 0.0068 - val_loss: 0.0032
# Epoch 8/10
# 54/54 [==============================] - 0s 672us/step - loss: 0.0066 - val_loss: 0.0075
# Epoch 9/10
# 54/54 [==============================] - 0s 846us/step - loss: 0.0057 - val_loss: 0.0159
# Epoch 10/10
# 54/54 [==============================] - 0s 803us/step - loss: 0.0054 - val_loss: 0.0051
#
# Fold: 6
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 50ms/step - loss: 0.4332 - val_loss: 0.2701
# Epoch 2/10
# 54/54 [==============================] - 0s 784us/step - loss: 0.1467 - val_loss: 0.0233
# Epoch 3/10
# 54/54 [==============================] - 0s 969us/step - loss: 0.1229 - val_loss: 0.2169
# Epoch 4/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0385 - val_loss: 0.0859
# Epoch 5/10
# 54/54 [==============================] - 0s 904us/step - loss: 0.0165 - val_loss: 0.0457
# Epoch 6/10
# 54/54 [==============================] - 0s 867us/step - loss: 0.0135 - val_loss: 0.1194
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0084 - val_loss: 0.0432
# Epoch 8/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0364
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0455
# Epoch 10/10
# 54/54 [==============================] - 0s 988us/step - loss: 0.0027 - val_loss: 0.0269
#
# Fold: 7
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 53ms/step - loss: 0.4588 - val_loss: 0.0081
# Epoch 2/10
# 54/54 [==============================] - 0s 836us/step - loss: 0.1168 - val_loss: 9.3856e-06
# Epoch 3/10
# 54/54 [==============================] - 0s 735us/step - loss: 0.0777 - val_loss: 0.0232
# Epoch 4/10
# 54/54 [==============================] - 0s 875us/step - loss: 0.0248 - val_loss: 3.1672e-04
# Epoch 5/10
# 54/54 [==============================] - 0s 721us/step - loss: 0.0144 - val_loss: 0.0078
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0068 - val_loss: 0.0172
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0028
# Epoch 8/10
# 54/54 [==============================] - 0s 991us/step - loss: 0.0030 - val_loss: 0.0108
# Epoch 9/10
# 54/54 [==============================] - 0s 714us/step - loss: 0.0021 - val_loss: 0.0066
# Epoch 10/10
# 54/54 [==============================] - 0s 714us/step - loss: 0.0019 - val_loss: 0.0055
#
# Fold: 8
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 54ms/step - loss: 0.3737 - val_loss: 0.0055
# Epoch 2/10
# 54/54 [==============================] - 0s 884us/step - loss: 0.1472 - val_loss: 0.0956
# Epoch 3/10
# 54/54 [==============================] - 0s 659us/step - loss: 0.0822 - val_loss: 3.2075e-04
# Epoch 4/10
# 54/54 [==============================] - 0s 846us/step - loss: 0.0335 - val_loss: 0.1062
# Epoch 5/10
# 54/54 [==============================] - 0s 673us/step - loss: 0.0255 - val_loss: 0.0024
# Epoch 6/10
# 54/54 [==============================] - 0s 930us/step - loss: 0.0153 - val_loss: 0.0283
# Epoch 7/10
# 54/54 [==============================] - 0s 931us/step - loss: 0.0115 - val_loss: 0.0049
# Epoch 8/10
# 54/54 [==============================] - 0s 828us/step - loss: 0.0070 - val_loss: 0.0205
# Epoch 9/10
# 54/54 [==============================] - 0s 912us/step - loss: 0.0072 - val_loss: 0.0236
# Epoch 10/10
# 54/54 [==============================] - 0s 700us/step - loss: 0.0043 - val_loss: 0.0412
#
# Fold: 9
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 52ms/step - loss: 0.4755 - val_loss: 0.0038
# Epoch 2/10
# 54/54 [==============================] - 0s 783us/step - loss: 0.1314 - val_loss: 0.0772
# Epoch 3/10
# 54/54 [==============================] - 0s 810us/step - loss: 0.0975 - val_loss: 0.0440
# Epoch 4/10
# 54/54 [==============================] - 0s 857us/step - loss: 0.0386 - val_loss: 0.0348
# Epoch 5/10
# 54/54 [==============================] - 0s 683us/step - loss: 0.0136 - val_loss: 0.0277
# Epoch 6/10
# 54/54 [==============================] - 0s 867us/step - loss: 0.0083 - val_loss: 0.0437
# Epoch 7/10
# 54/54 [==============================] - 0s 853us/step - loss: 0.0046 - val_loss: 0.0387
# Epoch 8/10
# 54/54 [==============================] - 0s 781us/step - loss: 0.0042 - val_loss: 0.0401
# Epoch 9/10
# 54/54 [==============================] - 0s 997us/step - loss: 0.0033 - val_loss: 0.0448
# Epoch 10/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0474
#
# Fold: 10
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 54ms/step - loss: 0.4349 - val_loss: 0.0248
# Epoch 2/10
# 54/54 [==============================] - 0s 818us/step - loss: 0.1389 - val_loss: 0.1241
# Epoch 3/10
# 54/54 [==============================] - 0s 802us/step - loss: 0.0553 - val_loss: 0.0048
# Epoch 4/10
# 54/54 [==============================] - 0s 865us/step - loss: 0.0330 - val_loss: 0.0109
# Epoch 5/10
# 54/54 [==============================] - 0s 844us/step - loss: 0.0143 - val_loss: 0.0027
# Epoch 6/10
# 54/54 [==============================] - 0s 706us/step - loss: 0.0098 - val_loss: 0.0153
# Epoch 7/10
# 54/54 [==============================] - 0s 926us/step - loss: 0.0058 - val_loss: 0.0196
# Epoch 8/10
# 54/54 [==============================] - 0s 909us/step - loss: 0.0092 - val_loss: 0.0545
# Epoch 9/10
# 54/54 [==============================] - 0s 933us/step - loss: 0.0096 - val_loss: 1.5533e-04
# Epoch 10/10
# 54/54 [==============================] - 0s 892us/step - loss: 0.0063 - val_loss: 0.0120
#
# Fold: 11
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 58ms/step - loss: 0.3970 - val_loss: 0.6500
# Epoch 2/10
# 54/54 [==============================] - 0s 880us/step - loss: 0.1417 - val_loss: 0.4474
# Epoch 3/10
# 54/54 [==============================] - 0s 802us/step - loss: 0.0561 - val_loss: 0.3543
# Epoch 4/10
# 54/54 [==============================] - 0s 742us/step - loss: 0.0314 - val_loss: 0.3256
# Epoch 5/10
# 54/54 [==============================] - 0s 825us/step - loss: 0.0129 - val_loss: 0.2332
# Epoch 6/10
# 54/54 [==============================] - 0s 720us/step - loss: 0.0105 - val_loss: 0.2167
# Epoch 7/10
# 54/54 [==============================] - 0s 877us/step - loss: 0.0098 - val_loss: 0.2769
# Epoch 8/10
# 54/54 [==============================] - 0s 883us/step - loss: 0.0062 - val_loss: 0.3038
# Epoch 9/10
# 54/54 [==============================] - 0s 892us/step - loss: 0.0098 - val_loss: 0.1524
# Epoch 10/10
# 54/54 [==============================] - 0s 703us/step - loss: 0.0075 - val_loss: 0.2490
#
# Fold: 12
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 57ms/step - loss: 0.5506 - val_loss: 0.0142
# Epoch 2/10
# 54/54 [==============================] - 0s 786us/step - loss: 0.1408 - val_loss: 0.5978
# Epoch 3/10
# 54/54 [==============================] - 0s 730us/step - loss: 0.0651 - val_loss: 0.0754
# Epoch 4/10
# 54/54 [==============================] - 0s 786us/step - loss: 0.0371 - val_loss: 0.2283
# Epoch 5/10
# 54/54 [==============================] - 0s 766us/step - loss: 0.0235 - val_loss: 0.0551
# Epoch 6/10
# 54/54 [==============================] - 0s 810us/step - loss: 0.0120 - val_loss: 0.2178
# Epoch 7/10
# 54/54 [==============================] - 0s 880us/step - loss: 0.0094 - val_loss: 0.0796
# Epoch 8/10
# 54/54 [==============================] - 0s 714us/step - loss: 0.0074 - val_loss: 0.2025
# Epoch 9/10
# 54/54 [==============================] - 0s 883us/step - loss: 0.0082 - val_loss: 0.0241
# Epoch 10/10
# 54/54 [==============================] - 0s 915us/step - loss: 0.0117 - val_loss: 0.1610
#
# Fold: 13
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 56ms/step - loss: 0.3758 - val_loss: 1.1570
# Epoch 2/10
# 54/54 [==============================] - 0s 849us/step - loss: 0.1873 - val_loss: 0.0809
# Epoch 3/10
# 54/54 [==============================] - 0s 970us/step - loss: 0.0474 - val_loss: 0.0464
# Epoch 4/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0218 - val_loss: 0.0597
# Epoch 5/10
# 54/54 [==============================] - 0s 969us/step - loss: 0.0130 - val_loss: 0.0234
# Epoch 6/10
# 54/54 [==============================] - 0s 947us/step - loss: 0.0091 - val_loss: 0.0349
# Epoch 7/10
# 54/54 [==============================] - 0s 775us/step - loss: 0.0120 - val_loss: 0.0648
# Epoch 8/10
# 54/54 [==============================] - 0s 812us/step - loss: 0.0059 - val_loss: 0.0020
# Epoch 9/10
# 54/54 [==============================] - 0s 852us/step - loss: 0.0051 - val_loss: 0.0303
# Epoch 10/10
# 54/54 [==============================] - 0s 775us/step - loss: 0.0036 - val_loss: 0.0232
#
# Fold: 14
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 56ms/step - loss: 0.4479 - val_loss: 0.8959
# Epoch 2/10
# 54/54 [==============================] - 0s 770us/step - loss: 0.1911 - val_loss: 0.0093
# Epoch 3/10
# 54/54 [==============================] - 0s 853us/step - loss: 0.0659 - val_loss: 0.2047
# Epoch 4/10
# 54/54 [==============================] - 0s 897us/step - loss: 0.0322 - val_loss: 0.0516
# Epoch 5/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0192 - val_loss: 0.1477
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0158 - val_loss: 0.0191
# Epoch 7/10
# 54/54 [==============================] - 0s 968us/step - loss: 0.0117 - val_loss: 0.1783
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0070 - val_loss: 0.0250
# Epoch 9/10
# 54/54 [==============================] - 0s 709us/step - loss: 0.0067 - val_loss: 0.1650
# Epoch 10/10
# 54/54 [==============================] - 0s 843us/step - loss: 0.0053 - val_loss: 0.0676
#
# Fold: 15
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 57ms/step - loss: 0.5166 - val_loss: 0.1118
# Epoch 2/10
# 54/54 [==============================] - 0s 873us/step - loss: 0.1045 - val_loss: 0.1742
# Epoch 3/10
# 54/54 [==============================] - 0s 739us/step - loss: 0.0426 - val_loss: 0.0760
# Epoch 4/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0242 - val_loss: 0.0517
# Epoch 5/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0169 - val_loss: 0.0426
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.1083
# Epoch 7/10
# 54/54 [==============================] - 0s 841us/step - loss: 0.0060 - val_loss: 0.1081
# Epoch 8/10
# 54/54 [==============================] - 0s 759us/step - loss: 0.0043 - val_loss: 0.1041
# Epoch 9/10
# 54/54 [==============================] - 0s 871us/step - loss: 0.0041 - val_loss: 0.2501
# Epoch 10/10
# 54/54 [==============================] - 0s 834us/step - loss: 0.0055 - val_loss: 0.0774
#
# Fold: 16
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 58ms/step - loss: 0.4626 - val_loss: 0.3295
# Epoch 2/10
# 54/54 [==============================] - 0s 803us/step - loss: 0.0756 - val_loss: 0.2527
# Epoch 3/10
# 54/54 [==============================] - 0s 753us/step - loss: 0.0506 - val_loss: 0.1192
# Epoch 4/10
# 54/54 [==============================] - 0s 853us/step - loss: 0.0260 - val_loss: 0.3397
# Epoch 5/10
# 54/54 [==============================] - 0s 958us/step - loss: 0.0217 - val_loss: 0.0043
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0162 - val_loss: 0.2311
# Epoch 7/10
# 54/54 [==============================] - 0s 955us/step - loss: 0.0112 - val_loss: 0.0019
# Epoch 8/10
# 54/54 [==============================] - 0s 858us/step - loss: 0.0136 - val_loss: 0.0249
# Epoch 9/10
# 54/54 [==============================] - 0s 746us/step - loss: 0.0063 - val_loss: 0.0642
# Epoch 10/10
# 54/54 [==============================] - 0s 867us/step - loss: 0.0042 - val_loss: 0.0200
#
# Fold: 17
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 58ms/step - loss: 0.5319 - val_loss: 0.1225
# Epoch 2/10
# 54/54 [==============================] - 0s 744us/step - loss: 0.0856 - val_loss: 0.0021
# Epoch 3/10
# 54/54 [==============================] - 0s 771us/step - loss: 0.0484 - val_loss: 0.0188
# Epoch 4/10
# 54/54 [==============================] - 0s 802us/step - loss: 0.0186 - val_loss: 4.1677e-05
# Epoch 5/10
# 54/54 [==============================] - 0s 718us/step - loss: 0.0106 - val_loss: 2.4694e-04
# Epoch 6/10
# 54/54 [==============================] - 0s 837us/step - loss: 0.0061 - val_loss: 1.4967e-05
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 8/10
# 54/54 [==============================] - 0s 873us/step - loss: 0.0036 - val_loss: 0.0046
# Epoch 9/10
# 54/54 [==============================] - 0s 888us/step - loss: 0.0043 - val_loss: 2.9755e-06
# Epoch 10/10
# 54/54 [==============================] - 0s 843us/step - loss: 0.0033 - val_loss: 0.0021
#
# Fold: 18
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 60ms/step - loss: 0.5183 - val_loss: 1.0219
# Epoch 2/10
# 54/54 [==============================] - 0s 752us/step - loss: 0.1037 - val_loss: 0.2541
# Epoch 3/10
# 54/54 [==============================] - 0s 826us/step - loss: 0.0729 - val_loss: 0.1460
# Epoch 4/10
# 54/54 [==============================] - 0s 737us/step - loss: 0.0455 - val_loss: 0.5416
# Epoch 5/10
# 54/54 [==============================] - 0s 813us/step - loss: 0.0306 - val_loss: 0.1779
# Epoch 6/10
# 54/54 [==============================] - 0s 757us/step - loss: 0.0250 - val_loss: 0.3450
# Epoch 7/10
# 54/54 [==============================] - 0s 817us/step - loss: 0.0174 - val_loss: 0.3762
# Epoch 8/10
# 54/54 [==============================] - 0s 848us/step - loss: 0.0124 - val_loss: 0.2027
# Epoch 9/10
# 54/54 [==============================] - 0s 826us/step - loss: 0.0066 - val_loss: 0.2084
# Epoch 10/10
# 54/54 [==============================] - 0s 987us/step - loss: 0.0055 - val_loss: 0.1969
#
# Fold: 19
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 60ms/step - loss: 0.4455 - val_loss: 0.0061
# Epoch 2/10
# 54/54 [==============================] - 0s 837us/step - loss: 0.1844 - val_loss: 0.0528
# Epoch 3/10
# 54/54 [==============================] - 0s 762us/step - loss: 0.0598 - val_loss: 6.4173e-04
# Epoch 4/10
# 54/54 [==============================] - 0s 844us/step - loss: 0.0310 - val_loss: 0.0213
# Epoch 5/10
# 54/54 [==============================] - 0s 840us/step - loss: 0.0189 - val_loss: 0.0108
# Epoch 6/10
# 54/54 [==============================] - 0s 827us/step - loss: 0.0103 - val_loss: 0.0221
# Epoch 7/10
# 54/54 [==============================] - 0s 880us/step - loss: 0.0078 - val_loss: 0.0301
# Epoch 8/10
# 54/54 [==============================] - 0s 774us/step - loss: 0.0036 - val_loss: 0.0388
# Epoch 9/10
# 54/54 [==============================] - 0s 862us/step - loss: 0.0019 - val_loss: 0.0383
# Epoch 10/10
# 54/54 [==============================] - 0s 766us/step - loss: 0.0011 - val_loss: 0.0510
#
# Fold: 20
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 60ms/step - loss: 0.4241 - val_loss: 0.0300
# Epoch 2/10
# 54/54 [==============================] - 0s 894us/step - loss: 0.1916 - val_loss: 0.0630
# Epoch 3/10
# 54/54 [==============================] - 0s 863us/step - loss: 0.0722 - val_loss: 2.1972e-04
# Epoch 4/10
# 54/54 [==============================] - 0s 823us/step - loss: 0.0411 - val_loss: 0.0171
# Epoch 5/10
# 54/54 [==============================] - 0s 729us/step - loss: 0.0216 - val_loss: 0.0036
# Epoch 6/10
# 54/54 [==============================] - 0s 871us/step - loss: 0.0088 - val_loss: 0.0014
# Epoch 7/10
# 54/54 [==============================] - 0s 740us/step - loss: 0.0060 - val_loss: 5.1279e-05
# Epoch 8/10
# 54/54 [==============================] - 0s 833us/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 1.2240e-04
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 1.3862e-04
#
# Fold: 21
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 62ms/step - loss: 0.4185 - val_loss: 0.0209
# Epoch 2/10
# 54/54 [==============================] - 0s 792us/step - loss: 0.1591 - val_loss: 6.4892e-04
# Epoch 3/10
# 54/54 [==============================] - 0s 839us/step - loss: 0.0799 - val_loss: 2.8309e-05
# Epoch 4/10
# 54/54 [==============================] - 0s 860us/step - loss: 0.0259 - val_loss: 1.7968e-04
# Epoch 5/10
# 54/54 [==============================] - 0s 695us/step - loss: 0.0144 - val_loss: 0.0712
# Epoch 6/10
# 54/54 [==============================] - 0s 859us/step - loss: 0.0151 - val_loss: 2.5290e-07
# Epoch 7/10
# 54/54 [==============================] - 0s 761us/step - loss: 0.0119 - val_loss: 0.0092
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0091 - val_loss: 0.0116
# Epoch 9/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0023
# Epoch 10/10
# 54/54 [==============================] - 0s 977us/step - loss: 0.0048 - val_loss: 6.1697e-04
#
# Fold: 22
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 61ms/step - loss: 0.6261 - val_loss: 0.1315
# Epoch 2/10
# 54/54 [==============================] - 0s 804us/step - loss: 0.1629 - val_loss: 0.1513
# Epoch 3/10
# 54/54 [==============================] - 0s 910us/step - loss: 0.0913 - val_loss: 0.0128
# Epoch 4/10
# 54/54 [==============================] - 0s 877us/step - loss: 0.0431 - val_loss: 0.0066
# Epoch 5/10
# 54/54 [==============================] - 0s 866us/step - loss: 0.0170 - val_loss: 0.0172
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0095 - val_loss: 0.0201
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0048 - val_loss: 0.0304
# Epoch 8/10
# 54/54 [==============================] - 0s 944us/step - loss: 0.0038 - val_loss: 0.0281
# Epoch 9/10
# 54/54 [==============================] - 0s 943us/step - loss: 0.0028 - val_loss: 0.0334
# Epoch 10/10
# 54/54 [==============================] - 0s 872us/step - loss: 0.0023 - val_loss: 0.0348
#
# Fold: 23
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 63ms/step - loss: 0.4534 - val_loss: 0.2067
# Epoch 2/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1170 - val_loss: 0.1218
# Epoch 3/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0494 - val_loss: 0.0968
# Epoch 4/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0186 - val_loss: 0.1195
# Epoch 5/10
# 54/54 [==============================] - 0s 919us/step - loss: 0.0187 - val_loss: 0.0890
# Epoch 6/10
# 54/54 [==============================] - 0s 842us/step - loss: 0.0141 - val_loss: 0.0720
# Epoch 7/10
# 54/54 [==============================] - 0s 874us/step - loss: 0.0084 - val_loss: 0.0363
# Epoch 8/10
# 54/54 [==============================] - 0s 880us/step - loss: 0.0058 - val_loss: 0.0324
# Epoch 9/10
# 54/54 [==============================] - 0s 966us/step - loss: 0.0039 - val_loss: 0.0500
# Epoch 10/10
# 54/54 [==============================] - 0s 874us/step - loss: 0.0038 - val_loss: 0.0295
#
# Fold: 24
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 64ms/step - loss: 0.5045 - val_loss: 0.3363
# Epoch 2/10
# 54/54 [==============================] - 0s 892us/step - loss: 0.1006 - val_loss: 0.3452
# Epoch 3/10
# 54/54 [==============================] - 0s 843us/step - loss: 0.0675 - val_loss: 0.0970
# Epoch 4/10
# 54/54 [==============================] - 0s 826us/step - loss: 0.0310 - val_loss: 0.2810
# Epoch 5/10
# 54/54 [==============================] - 0s 815us/step - loss: 0.0130 - val_loss: 0.4209
# Epoch 6/10
# 54/54 [==============================] - 0s 936us/step - loss: 0.0081 - val_loss: 0.1303
# Epoch 7/10
# 54/54 [==============================] - 0s 866us/step - loss: 0.0052 - val_loss: 0.2929
# Epoch 8/10
# 54/54 [==============================] - 0s 818us/step - loss: 0.0021 - val_loss: 0.1626
# Epoch 9/10
# 54/54 [==============================] - 0s 808us/step - loss: 0.0019 - val_loss: 0.2233
# Epoch 10/10
# 54/54 [==============================] - 0s 807us/step - loss: 0.0015 - val_loss: 0.2743
#
# Fold: 25
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 3s 65ms/step - loss: 0.4443 - val_loss: 0.4521
# Epoch 2/10
# 54/54 [==============================] - 0s 785us/step - loss: 0.1810 - val_loss: 0.0338
# Epoch 3/10
# 54/54 [==============================] - 0s 910us/step - loss: 0.0880 - val_loss: 0.1016
# Epoch 4/10
# 54/54 [==============================] - 0s 882us/step - loss: 0.0568 - val_loss: 0.0018
# Epoch 5/10
# 54/54 [==============================] - 0s 906us/step - loss: 0.0336 - val_loss: 0.0070
# Epoch 6/10
# 54/54 [==============================] - 0s 837us/step - loss: 0.0141 - val_loss: 0.0159
# Epoch 7/10
# 54/54 [==============================] - 0s 759us/step - loss: 0.0067 - val_loss: 0.0025
# Epoch 8/10
# 54/54 [==============================] - 0s 815us/step - loss: 0.0042 - val_loss: 0.0081
# Epoch 9/10
# 54/54 [==============================] - 0s 811us/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 10/10
# 54/54 [==============================] - 0s 820us/step - loss: 0.0027 - val_loss: 0.0059
#
# Fold: 26
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 66ms/step - loss: 0.4799 - val_loss: 0.1932
# Epoch 2/10
# 54/54 [==============================] - 0s 900us/step - loss: 0.2166 - val_loss: 2.3230e-04
# Epoch 3/10
# 54/54 [==============================] - 0s 876us/step - loss: 0.0648 - val_loss: 0.0160
# Epoch 4/10
# 54/54 [==============================] - 0s 764us/step - loss: 0.0320 - val_loss: 4.2970e-04
# Epoch 5/10
# 54/54 [==============================] - 0s 786us/step - loss: 0.0186 - val_loss: 0.0066
# Epoch 6/10
# 54/54 [==============================] - 0s 819us/step - loss: 0.0156 - val_loss: 0.0170
# Epoch 7/10
# 54/54 [==============================] - 0s 839us/step - loss: 0.0121 - val_loss: 0.0053
# Epoch 8/10
# 54/54 [==============================] - 0s 878us/step - loss: 0.0130 - val_loss: 0.0081
# Epoch 9/10
# 54/54 [==============================] - 0s 942us/step - loss: 0.0041 - val_loss: 0.0050
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0013
#
# Fold: 27
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 65ms/step - loss: 0.4614 - val_loss: 0.1742
# Epoch 2/10
# 54/54 [==============================] - 0s 877us/step - loss: 0.2065 - val_loss: 0.0011
# Epoch 3/10
# 54/54 [==============================] - 0s 993us/step - loss: 0.1103 - val_loss: 0.2684
# Epoch 4/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0444 - val_loss: 0.0094
# Epoch 5/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0240 - val_loss: 0.1183
# Epoch 6/10
# 54/54 [==============================] - 0s 874us/step - loss: 0.0120 - val_loss: 0.0914
# Epoch 7/10
# 54/54 [==============================] - 0s 831us/step - loss: 0.0065 - val_loss: 0.0566
# Epoch 8/10
# 54/54 [==============================] - 0s 767us/step - loss: 0.0049 - val_loss: 0.1247
# Epoch 9/10
# 54/54 [==============================] - 0s 978us/step - loss: 0.0024 - val_loss: 0.1327
# Epoch 10/10
# 54/54 [==============================] - 0s 947us/step - loss: 0.0018 - val_loss: 0.0677
#
# Fold: 28
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 66ms/step - loss: 0.5152 - val_loss: 0.2959
# Epoch 2/10
# 54/54 [==============================] - 0s 922us/step - loss: 0.1294 - val_loss: 0.0079
# Epoch 3/10
# 54/54 [==============================] - 0s 905us/step - loss: 0.0599 - val_loss: 0.0354
# Epoch 4/10
# 54/54 [==============================] - 0s 907us/step - loss: 0.0198 - val_loss: 0.0990
# Epoch 5/10
# 54/54 [==============================] - 0s 981us/step - loss: 0.0144 - val_loss: 0.0684
# Epoch 6/10
# 54/54 [==============================] - 0s 852us/step - loss: 0.0084 - val_loss: 0.0922
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0071 - val_loss: 0.0656
# Epoch 8/10
# 54/54 [==============================] - 0s 817us/step - loss: 0.0041 - val_loss: 0.0722
# Epoch 9/10
# 54/54 [==============================] - 0s 958us/step - loss: 0.0024 - val_loss: 0.0702
# Epoch 10/10
# 54/54 [==============================] - 0s 836us/step - loss: 0.0014 - val_loss: 0.0642
#
# Fold: 29
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 67ms/step - loss: 0.4857 - val_loss: 0.1620
# Epoch 2/10
# 54/54 [==============================] - 0s 901us/step - loss: 0.1249 - val_loss: 0.4118
# Epoch 3/10
# 54/54 [==============================] - 0s 888us/step - loss: 0.0568 - val_loss: 0.2512
# Epoch 4/10
# 54/54 [==============================] - 0s 870us/step - loss: 0.0258 - val_loss: 0.3181
# Epoch 5/10
# 54/54 [==============================] - 0s 904us/step - loss: 0.0144 - val_loss: 0.3459
# Epoch 6/10
# 54/54 [==============================] - 0s 753us/step - loss: 0.0085 - val_loss: 0.2775
# Epoch 7/10
# 54/54 [==============================] - 0s 887us/step - loss: 0.0044 - val_loss: 0.2388
# Epoch 8/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.2529
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.3194
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.2219
#
# Fold: 30
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 69ms/step - loss: 0.5693 - val_loss: 0.3606
# Epoch 2/10
# 54/54 [==============================] - 0s 839us/step - loss: 0.1488 - val_loss: 0.4104
# Epoch 3/10
# 54/54 [==============================] - 0s 822us/step - loss: 0.0833 - val_loss: 0.0448
# Epoch 4/10
# 54/54 [==============================] - 0s 959us/step - loss: 0.0418 - val_loss: 0.0713
# Epoch 5/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0178 - val_loss: 0.0645
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0092 - val_loss: 0.0086
# Epoch 7/10
# 54/54 [==============================] - 0s 942us/step - loss: 0.0050 - val_loss: 0.0159
# Epoch 8/10
# 54/54 [==============================] - 0s 921us/step - loss: 0.0036 - val_loss: 0.0081
# Epoch 9/10
# 54/54 [==============================] - 0s 921us/step - loss: 0.0029 - val_loss: 0.0071
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0024
#
# Fold: 31
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 69ms/step - loss: 0.4451 - val_loss: 0.0050
# Epoch 2/10
# 54/54 [==============================] - 0s 884us/step - loss: 0.1473 - val_loss: 1.7181e-06
# Epoch 3/10
# 54/54 [==============================] - 0s 874us/step - loss: 0.0967 - val_loss: 0.0605
# Epoch 4/10
# 54/54 [==============================] - 0s 830us/step - loss: 0.0410 - val_loss: 0.0502
# Epoch 5/10
# 54/54 [==============================] - 0s 837us/step - loss: 0.0352 - val_loss: 0.0346
# Epoch 6/10
# 54/54 [==============================] - 0s 908us/step - loss: 0.0342 - val_loss: 0.1377
# Epoch 7/10
# 54/54 [==============================] - 0s 976us/step - loss: 0.0142 - val_loss: 0.0588
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0963
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0801
# Epoch 10/10
# 54/54 [==============================] - 0s 919us/step - loss: 0.0023 - val_loss: 0.0796
#
# Fold: 32
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 69ms/step - loss: 0.4198 - val_loss: 0.3401
# Epoch 2/10
# 54/54 [==============================] - 0s 880us/step - loss: 0.2031 - val_loss: 0.1101
# Epoch 3/10
# 54/54 [==============================] - 0s 830us/step - loss: 0.0622 - val_loss: 0.0917
# Epoch 4/10
# 54/54 [==============================] - 0s 822us/step - loss: 0.0364 - val_loss: 0.0225
# Epoch 5/10
# 54/54 [==============================] - 0s 873us/step - loss: 0.0148 - val_loss: 0.0220
# Epoch 6/10
# 54/54 [==============================] - 0s 901us/step - loss: 0.0108 - val_loss: 0.0191
# Epoch 7/10
# 54/54 [==============================] - 0s 907us/step - loss: 0.0092 - val_loss: 0.0115
# Epoch 8/10
# 54/54 [==============================] - 0s 879us/step - loss: 0.0053 - val_loss: 0.0207
# Epoch 9/10
# 54/54 [==============================] - 0s 856us/step - loss: 0.0059 - val_loss: 0.0149
# Epoch 10/10
# 54/54 [==============================] - 0s 806us/step - loss: 0.0038 - val_loss: 0.0135
#
# Fold: 33
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 70ms/step - loss: 0.4385 - val_loss: 0.2640
# Epoch 2/10
# 54/54 [==============================] - 0s 920us/step - loss: 0.1142 - val_loss: 0.0902
# Epoch 3/10
# 54/54 [==============================] - 0s 829us/step - loss: 0.0573 - val_loss: 0.0580
# Epoch 4/10
# 54/54 [==============================] - 0s 870us/step - loss: 0.0443 - val_loss: 0.1160
# Epoch 5/10
# 54/54 [==============================] - 0s 857us/step - loss: 0.0166 - val_loss: 0.1396
# Epoch 6/10
# 54/54 [==============================] - 0s 934us/step - loss: 0.0084 - val_loss: 0.1236
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.1118
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.1244
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.1337
# Epoch 10/10
# 54/54 [==============================] - 0s 925us/step - loss: 0.0018 - val_loss: 0.1042
#
# Fold: 34
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 72ms/step - loss: 0.4038 - val_loss: 0.5141
# Epoch 2/10
# 54/54 [==============================] - 0s 903us/step - loss: 0.2145 - val_loss: 0.3593
# Epoch 3/10
# 54/54 [==============================] - 0s 922us/step - loss: 0.0734 - val_loss: 0.2646
# Epoch 4/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0333 - val_loss: 0.2563
# Epoch 5/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0206 - val_loss: 0.2393
# Epoch 6/10
# 54/54 [==============================] - 0s 998us/step - loss: 0.0123 - val_loss: 0.3025
# Epoch 7/10
# 54/54 [==============================] - 0s 947us/step - loss: 0.0058 - val_loss: 0.2932
# Epoch 8/10
# 54/54 [==============================] - 0s 921us/step - loss: 0.0049 - val_loss: 0.4217
# Epoch 9/10
# 54/54 [==============================] - 0s 877us/step - loss: 0.0045 - val_loss: 0.2561
# Epoch 10/10
# 54/54 [==============================] - 0s 875us/step - loss: 0.0037 - val_loss: 0.3176
#
# Fold: 35
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 72ms/step - loss: 0.5441 - val_loss: 0.0215
# Epoch 2/10
# 54/54 [==============================] - 0s 939us/step - loss: 0.1272 - val_loss: 0.0306
# Epoch 3/10
# 54/54 [==============================] - 0s 917us/step - loss: 0.0831 - val_loss: 0.0828
# Epoch 4/10
# 54/54 [==============================] - 0s 963us/step - loss: 0.0333 - val_loss: 0.0061
# Epoch 5/10
# 54/54 [==============================] - 0s 944us/step - loss: 0.0205 - val_loss: 0.0374
# Epoch 6/10
# 54/54 [==============================] - 0s 885us/step - loss: 0.0125 - val_loss: 0.0117
# Epoch 7/10
# 54/54 [==============================] - 0s 948us/step - loss: 0.0079 - val_loss: 0.0612
# Epoch 8/10
# 54/54 [==============================] - 0s 922us/step - loss: 0.0072 - val_loss: 0.0240
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0572
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0827
#
# Fold: 36
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 73ms/step - loss: 0.6225 - val_loss: 0.0871
# Epoch 2/10
# 54/54 [==============================] - 0s 930us/step - loss: 0.1234 - val_loss: 0.0727
# Epoch 3/10
# 54/54 [==============================] - 0s 998us/step - loss: 0.0806 - val_loss: 0.0014
# Epoch 4/10
# 54/54 [==============================] - 0s 816us/step - loss: 0.0344 - val_loss: 0.0151
# Epoch 5/10
# 54/54 [==============================] - 0s 928us/step - loss: 0.0180 - val_loss: 4.1931e-04
# Epoch 6/10
# 54/54 [==============================] - 0s 923us/step - loss: 0.0116 - val_loss: 0.0119
# Epoch 7/10
# 54/54 [==============================] - 0s 923us/step - loss: 0.0104 - val_loss: 5.1290e-04
# Epoch 8/10
# 54/54 [==============================] - 0s 865us/step - loss: 0.0060 - val_loss: 0.0195
# Epoch 9/10
# 54/54 [==============================] - 0s 951us/step - loss: 0.0042 - val_loss: 0.0022
# Epoch 10/10
# 54/54 [==============================] - 0s 994us/step - loss: 0.0031 - val_loss: 0.0170
#
# Fold: 37
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 73ms/step - loss: 0.5346 - val_loss: 0.0439
# Epoch 2/10
# 54/54 [==============================] - 0s 975us/step - loss: 0.1456 - val_loss: 0.0084
# Epoch 3/10
# 54/54 [==============================] - 0s 956us/step - loss: 0.0522 - val_loss: 0.0896
# Epoch 4/10
# 54/54 [==============================] - 0s 936us/step - loss: 0.0169 - val_loss: 0.0042
# Epoch 5/10
# 54/54 [==============================] - 0s 959us/step - loss: 0.0156 - val_loss: 0.0610
# Epoch 6/10
# 54/54 [==============================] - 0s 866us/step - loss: 0.0136 - val_loss: 0.0170
# Epoch 7/10
# 54/54 [==============================] - 0s 884us/step - loss: 0.0135 - val_loss: 0.0104
# Epoch 8/10
# 54/54 [==============================] - 0s 982us/step - loss: 0.0086 - val_loss: 0.0192
# Epoch 9/10
# 54/54 [==============================] - 0s 939us/step - loss: 0.0127 - val_loss: 0.0406
# Epoch 10/10
# 54/54 [==============================] - 0s 908us/step - loss: 0.0081 - val_loss: 0.0154
#
# Fold: 38
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 74ms/step - loss: 0.4401 - val_loss: 0.2713
# Epoch 2/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0924 - val_loss: 0.0511
# Epoch 3/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0858 - val_loss: 0.1173
# Epoch 4/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0497 - val_loss: 0.0257
# Epoch 5/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 5.3154e-06
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0141 - val_loss: 0.0262
# Epoch 7/10
# 54/54 [==============================] - 0s 872us/step - loss: 0.0102 - val_loss: 0.0066
# Epoch 8/10
# 54/54 [==============================] - 0s 880us/step - loss: 0.0053 - val_loss: 0.0531
# Epoch 9/10
# 54/54 [==============================] - 0s 972us/step - loss: 0.0038 - val_loss: 0.0172
# Epoch 10/10
# 54/54 [==============================] - 0s 907us/step - loss: 0.0038 - val_loss: 0.0099
#
# Fold: 39
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 75ms/step - loss: 0.4113 - val_loss: 0.0686
# Epoch 2/10
# 54/54 [==============================] - 0s 957us/step - loss: 0.2101 - val_loss: 0.0059
# Epoch 3/10
# 54/54 [==============================] - 0s 936us/step - loss: 0.1237 - val_loss: 0.0098
# Epoch 4/10
# 54/54 [==============================] - 0s 991us/step - loss: 0.0373 - val_loss: 0.0056
# Epoch 5/10
# 54/54 [==============================] - 0s 933us/step - loss: 0.0157 - val_loss: 0.0150
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0095 - val_loss: 0.0168
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0170
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.0223
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0176
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0201
#
# Fold: 40
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 77ms/step - loss: 0.4268 - val_loss: 0.0164
# Epoch 2/10
# 54/54 [==============================] - 0s 941us/step - loss: 0.2101 - val_loss: 0.0355
# Epoch 3/10
# 54/54 [==============================] - 0s 921us/step - loss: 0.0676 - val_loss: 0.0591
# Epoch 4/10
# 54/54 [==============================] - 0s 933us/step - loss: 0.0522 - val_loss: 0.0449
# Epoch 5/10
# 54/54 [==============================] - 0s 993us/step - loss: 0.0140 - val_loss: 0.0176
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0083 - val_loss: 0.0222
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0058 - val_loss: 0.0453
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0252
# Epoch 9/10
# 54/54 [==============================] - 0s 969us/step - loss: 0.0028 - val_loss: 0.0315
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0247
#
# Fold: 41
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 77ms/step - loss: 0.5643 - val_loss: 3.2350
# Epoch 2/10
# 54/54 [==============================] - 0s 965us/step - loss: 0.1439 - val_loss: 0.2834
# Epoch 3/10
# 54/54 [==============================] - 0s 928us/step - loss: 0.0978 - val_loss: 0.4526
# Epoch 4/10
# 54/54 [==============================] - 0s 915us/step - loss: 0.0345 - val_loss: 0.2954
# Epoch 5/10
# 54/54 [==============================] - 0s 920us/step - loss: 0.0239 - val_loss: 0.1876
# Epoch 6/10
# 54/54 [==============================] - 0s 981us/step - loss: 0.0123 - val_loss: 0.1409
# Epoch 7/10
# 54/54 [==============================] - 0s 957us/step - loss: 0.0076 - val_loss: 0.0962
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0088 - val_loss: 0.0812
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0996
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0616
#
# Fold: 42
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 77ms/step - loss: 0.5950 - val_loss: 0.1735
# Epoch 2/10
# 54/54 [==============================] - 0s 951us/step - loss: 0.1289 - val_loss: 0.0847
# Epoch 3/10
# 54/54 [==============================] - 0s 891us/step - loss: 0.0712 - val_loss: 0.0292
# Epoch 4/10
# 54/54 [==============================] - 0s 861us/step - loss: 0.0354 - val_loss: 0.0040
# Epoch 5/10
# 54/54 [==============================] - 0s 899us/step - loss: 0.0200 - val_loss: 0.0191
# Epoch 6/10
# 54/54 [==============================] - 0s 901us/step - loss: 0.0150 - val_loss: 0.0332
# Epoch 7/10
# 54/54 [==============================] - 0s 931us/step - loss: 0.0085 - val_loss: 0.0293
# Epoch 8/10
# 54/54 [==============================] - 0s 997us/step - loss: 0.0081 - val_loss: 0.0109
# Epoch 9/10
# 54/54 [==============================] - 0s 965us/step - loss: 0.0039 - val_loss: 0.0161
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0183
#
# Fold: 43
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 78ms/step - loss: 0.4498 - val_loss: 0.1174
# Epoch 2/10
# 54/54 [==============================] - 0s 983us/step - loss: 0.1805 - val_loss: 0.2058
# Epoch 3/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0684 - val_loss: 0.0622
# Epoch 4/10
# 54/54 [==============================] - 0s 919us/step - loss: 0.0513 - val_loss: 0.0479
# Epoch 5/10
# 54/54 [==============================] - 0s 980us/step - loss: 0.0261 - val_loss: 0.1417
# Epoch 6/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.1001
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0558
# Epoch 8/10
# 54/54 [==============================] - 0s 941us/step - loss: 0.0032 - val_loss: 0.0546
# Epoch 9/10
# 54/54 [==============================] - 0s 886us/step - loss: 0.0021 - val_loss: 0.1126
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0576
#
# Fold: 44
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 78ms/step - loss: 0.4842 - val_loss: 0.0136
# Epoch 2/10
# 54/54 [==============================] - 0s 957us/step - loss: 0.1695 - val_loss: 0.3179
# Epoch 3/10
# 54/54 [==============================] - 0s 905us/step - loss: 0.0691 - val_loss: 0.1081
# Epoch 4/10
# 54/54 [==============================] - 0s 965us/step - loss: 0.0460 - val_loss: 0.0135
# Epoch 5/10
# 54/54 [==============================] - 0s 906us/step - loss: 0.0200 - val_loss: 0.0386
# Epoch 6/10
# 54/54 [==============================] - 0s 930us/step - loss: 0.0144 - val_loss: 0.0039
# Epoch 7/10
# 54/54 [==============================] - 0s 908us/step - loss: 0.0117 - val_loss: 0.0110
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0090
# Epoch 10/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0058
#
# Fold: 45
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 81ms/step - loss: 0.3983 - val_loss: 0.0258
# Epoch 2/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1168 - val_loss: 0.0549
# Epoch 3/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0389 - val_loss: 0.0336
# Epoch 4/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0243 - val_loss: 0.0034
# Epoch 5/10
# 54/54 [==============================] - 0s 968us/step - loss: 0.0264 - val_loss: 0.0093
# Epoch 6/10
# 54/54 [==============================] - 0s 905us/step - loss: 0.0160 - val_loss: 0.0147
# Epoch 7/10
# 54/54 [==============================] - 0s 870us/step - loss: 0.0090 - val_loss: 1.6369e-04
# Epoch 8/10
# 54/54 [==============================] - 0s 893us/step - loss: 0.0101 - val_loss: 0.0020
# Epoch 9/10
# 54/54 [==============================] - 0s 952us/step - loss: 0.0075 - val_loss: 0.0019
# Epoch 10/10
# 54/54 [==============================] - 0s 915us/step - loss: 0.0064 - val_loss: 2.8540e-06
#
# Fold: 46
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 81ms/step - loss: 0.3906 - val_loss: 0.1618
# Epoch 2/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1348 - val_loss: 0.1701
# Epoch 3/10
# 54/54 [==============================] - 0s 939us/step - loss: 0.0545 - val_loss: 0.0201
# Epoch 4/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0311 - val_loss: 0.0269
# Epoch 5/10
# 54/54 [==============================] - 0s 938us/step - loss: 0.0167 - val_loss: 0.0081
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0083 - val_loss: 0.0097
# Epoch 7/10
# 54/54 [==============================] - 0s 957us/step - loss: 0.0062 - val_loss: 0.0222
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0120
# Epoch 9/10
# 54/54 [==============================] - 0s 980us/step - loss: 0.0050 - val_loss: 0.0206
# Epoch 10/10
# 54/54 [==============================] - 0s 933us/step - loss: 0.0048 - val_loss: 0.0114
#
# Fold: 47
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 81ms/step - loss: 0.4184 - val_loss: 0.3163
# Epoch 2/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1436 - val_loss: 0.2381
# Epoch 3/10
# 54/54 [==============================] - 0s 922us/step - loss: 0.0499 - val_loss: 0.0636
# Epoch 4/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0273 - val_loss: 0.0869
# Epoch 5/10
# 54/54 [==============================] - 0s 984us/step - loss: 0.0203 - val_loss: 0.0638
# Epoch 6/10
# 54/54 [==============================] - 0s 961us/step - loss: 0.0160 - val_loss: 0.0642
# Epoch 7/10
# 54/54 [==============================] - 0s 970us/step - loss: 0.0094 - val_loss: 0.0627
# Epoch 8/10
# 54/54 [==============================] - 0s 919us/step - loss: 0.0068 - val_loss: 0.0781
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0700
# Epoch 10/10
# 54/54 [==============================] - 0s 955us/step - loss: 0.0040 - val_loss: 0.0658
#
# Fold: 48
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 4s 81ms/step - loss: 0.4602 - val_loss: 1.8596
# Epoch 2/10
# 54/54 [==============================] - 0s 964us/step - loss: 0.2564 - val_loss: 9.5585e-04
# Epoch 3/10
# 54/54 [==============================] - 0s 943us/step - loss: 0.1132 - val_loss: 0.0578
# Epoch 4/10
# 54/54 [==============================] - 0s 917us/step - loss: 0.0404 - val_loss: 0.0875
# Epoch 5/10
# 54/54 [==============================] - 0s 887us/step - loss: 0.0220 - val_loss: 0.0085
# Epoch 6/10
# 54/54 [==============================] - 0s 951us/step - loss: 0.0122 - val_loss: 0.0357
# Epoch 7/10
# 54/54 [==============================] - 0s 920us/step - loss: 0.0063 - val_loss: 0.0057
# Epoch 8/10
# 54/54 [==============================] - 0s 907us/step - loss: 0.0042 - val_loss: 0.0144
# Epoch 9/10
# 54/54 [==============================] - 0s 911us/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0069
#
# Fold: 49
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 5s 83ms/step - loss: 0.4663 - val_loss: 1.0054
# Epoch 2/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1780 - val_loss: 9.5924e-04
# Epoch 3/10
# 54/54 [==============================] - 0s 966us/step - loss: 0.0757 - val_loss: 0.2385
# Epoch 4/10
# 54/54 [==============================] - 0s 976us/step - loss: 0.0239 - val_loss: 0.1277
# Epoch 5/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0156 - val_loss: 0.1563
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0079 - val_loss: 0.1476
# Epoch 7/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0051 - val_loss: 0.1580
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.1296
# Epoch 9/10
# 54/54 [==============================] - 0s 966us/step - loss: 0.0026 - val_loss: 0.1345
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.1551
#
# Fold: 50
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 5s 84ms/step - loss: 0.3441 - val_loss: 0.9610
# Epoch 2/10
# 54/54 [==============================] - 0s 985us/step - loss: 0.1484 - val_loss: 0.0024
# Epoch 3/10
# 54/54 [==============================] - 0s 905us/step - loss: 0.1004 - val_loss: 0.5730
# Epoch 4/10
# 54/54 [==============================] - 0s 963us/step - loss: 0.0856 - val_loss: 0.0143
# Epoch 5/10
# 54/54 [==============================] - 0s 929us/step - loss: 0.0609 - val_loss: 0.1262
# Epoch 6/10
# 54/54 [==============================] - 0s 951us/step - loss: 0.0226 - val_loss: 0.0756
# Epoch 7/10
# 54/54 [==============================] - 0s 988us/step - loss: 0.0108 - val_loss: 0.0371
# Epoch 8/10
# 54/54 [==============================] - 0s 953us/step - loss: 0.0088 - val_loss: 0.1077
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0632
# Epoch 10/10
# 54/54 [==============================] - 0s 934us/step - loss: 0.0027 - val_loss: 0.0978
#
# Fold: 51
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 5s 85ms/step - loss: 0.5910 - val_loss: 0.0016
# Epoch 2/10
# 54/54 [==============================] - 0s 998us/step - loss: 0.1409 - val_loss: 0.8536
# Epoch 3/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0735 - val_loss: 0.1015
# Epoch 4/10
# 54/54 [==============================] - 0s 926us/step - loss: 0.0250 - val_loss: 0.2150
# Epoch 5/10
# 54/54 [==============================] - 0s 947us/step - loss: 0.0127 - val_loss: 0.1708
# Epoch 6/10
# 54/54 [==============================] - 0s 947us/step - loss: 0.0090 - val_loss: 0.1393
# Epoch 7/10
# 54/54 [==============================] - 0s 942us/step - loss: 0.0049 - val_loss: 0.1503
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.1313
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.1409
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.1184
#
# Fold: 52
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 5s 84ms/step - loss: 0.4783 - val_loss: 0.0234
# Epoch 2/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1044 - val_loss: 0.1862
# Epoch 3/10
# 54/54 [==============================] - 0s 973us/step - loss: 0.0558 - val_loss: 0.0075
# Epoch 4/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0411 - val_loss: 0.1132
# Epoch 5/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0303 - val_loss: 0.0647
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0174 - val_loss: 0.1412
# Epoch 7/10
# 54/54 [==============================] - 0s 961us/step - loss: 0.0120 - val_loss: 0.0542
# Epoch 8/10
# 54/54 [==============================] - 0s 994us/step - loss: 0.0053 - val_loss: 0.1040
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0783
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0905
#
# Fold: 53
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 5s 86ms/step - loss: 0.4477 - val_loss: 0.3249
# Epoch 2/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1415 - val_loss: 0.0257
# Epoch 3/10
# 54/54 [==============================] - 0s 927us/step - loss: 0.1145 - val_loss: 0.7428
# Epoch 4/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0962 - val_loss: 0.0492
# Epoch 5/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0638 - val_loss: 0.2420
# Epoch 6/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0451 - val_loss: 0.0258
# Epoch 7/10
# 54/54 [==============================] - 0s 989us/step - loss: 0.0142 - val_loss: 0.1814
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0080 - val_loss: 0.0813
# Epoch 9/10
# 54/54 [==============================] - 0s 970us/step - loss: 0.0064 - val_loss: 0.1942
# Epoch 10/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0294
#
# Fold: 54
# Train on 54 samples, validate on 1 samples
# Epoch 1/10
# 54/54 [==============================] - 5s 88ms/step - loss: 0.5388 - val_loss: 0.1737
# Epoch 2/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1040 - val_loss: 0.1743
# Epoch 3/10
# 54/54 [==============================] - 0s 957us/step - loss: 0.0614 - val_loss: 0.0918
# Epoch 4/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0379 - val_loss: 0.1147
# Epoch 5/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0164 - val_loss: 0.0413
# Epoch 6/10
# 54/54 [==============================] - 0s 944us/step - loss: 0.0098 - val_loss: 0.0428
# Epoch 7/10
# 54/54 [==============================] - 0s 940us/step - loss: 0.0081 - val_loss: 0.0510
# Epoch 8/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.0393
# Epoch 9/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0383
# Epoch 10/10
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0393

# %%
plt.figure(figsize=(16, 8))
plt.plot(range(len(results_loss)), results_loss, 'k')
plt.plot(range(len(results_loss)), results_loss, 'ko')
plt.plot(range(len(results_val_loss)), results_val_loss, 'r')
plt.plot(range(len(results_val_loss)), results_val_loss, 'ro')
plt.legend(['loss', '', 'val_loss', ''], fontsize=20)
plt.xlabel('Fold #', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.title(f'loss: {results_loss[-1]} / val_loss: {results_val_loss[-1]}', fontsize=20)
plt.yscale('log')
plt.grid(True)
plt.show()

plt.figure(figsize=(16, 8))
plt.plot(range(len(results_loss)), results_loss, 'k')
plt.plot(range(len(results_loss)), results_loss, 'ko')
plt.plot(range(len(results_val_loss)), results_val_loss, 'r')
plt.plot(range(len(results_val_loss)), results_val_loss, 'ro')
plt.legend(['loss', '', 'val_loss', ''], fontsize=20)
plt.xlabel('Fold #', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.title(f'loss: {results_loss[-1]} / val_loss: {results_val_loss[-1]}', fontsize=20)
plt.grid(True)
plt.show()

print(f'Stats: Mean (std)')
print(f'loss: {results_loss.mean()} ({results_loss.std()})')
print(f'val_loss: {results_val_loss.mean()} ({results_val_loss.std()})')
# Out:
# Stats: Mean (std)
# loss: 0.003650769973120822 (0.001911411066439139)
# val_loss: 0.07013794496158632 (0.10107799797896251)

# %%
import matplotlib.pyplot as plt
import numpy as np
import tcc_utils
import tratamento_dados_empresa
from sklearn.preprocessing import StandardScaler
from keras.initializers import glorot_normal as gl_normal
from sklearn.model_selection import KFold

x_csv_path = '../data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = '../data/grendene-cotacao-raw.csv'

x, y = tratamento_dados_empresa.get_x_y(x_csv_path, y_csv_path)


# Feature Scaling X
x_scaler = StandardScaler()
x = x_scaler.fit_transform(x)

# Feature Scaling y
y_scaler = StandardScaler()
y = y_scaler.fit_transform(y)

# Generate hidden layer # of nodes
number_hidden_layer = round(x.shape[1]*1.5)

# LOOCV: k-fold cross validation (folds=x.shape[0], shuffle=True, seed=1)
kfold = KFold(x.shape[0], True, 1)

# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['relu', 'relu']

i = 0
results_loss = np.array([])
results_val_loss = np.array([])

for train, test in kfold.split(x):
    print(f'Fold: {i}')
    i += 1
    glorot_normal = gl_normal(seed=0)
    deep_model = tcc_utils.deep_model(x, glorot_normal, layers, activations)
    deep_history = deep_model.fit(x[train,:], y[train,:], validation_data=(x[test,:], y[test,:]), batch_size=4, epochs=1, verbose=1)
    results_loss = np.append([results_loss], [[deep_history.history["loss"][-1]]])
    results_val_loss = np.append([results_val_loss], [[deep_history.history["val_loss"][-1]]])
    print('')
# Out:
# Fold: 0
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 5s 98ms/step - loss: 0.4807 - val_loss: 0.3502
#
# Fold: 1
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 5s 91ms/step - loss: 0.4465 - val_loss: 0.0058
#
# Fold: 2
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 5s 92ms/step - loss: 0.3964 - val_loss: 0.1302
#
# Fold: 3
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 5s 93ms/step - loss: 0.4136 - val_loss: 0.2662
#
# Fold: 4
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 5s 93ms/step - loss: 0.2616 - val_loss: 5.2636e-04
#
# Fold: 5
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 5s 95ms/step - loss: 0.4661 - val_loss: 5.3033e-04
#
# Fold: 6
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 5s 100ms/step - loss: 0.4103 - val_loss: 0.0463
#
# Fold: 7
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 5s 100ms/step - loss: 0.4409 - val_loss: 0.0172
#
# Fold: 8
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 105ms/step - loss: 0.4442 - val_loss: 0.0741
#
# Fold: 9
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 5s 101ms/step - loss: 0.3743 - val_loss: 0.0038
#
# Fold: 10
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 5s 98ms/step - loss: 0.4644 - val_loss: 0.1555
#
# Fold: 11
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 127ms/step - loss: 0.5350 - val_loss: 0.2958
#
# Fold: 12
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 10s 188ms/step - loss: 0.4126 - val_loss: 0.3463
#
# Fold: 13
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 106ms/step - loss: 0.5022 - val_loss: 1.7937
#
# Fold: 14
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 105ms/step - loss: 0.4768 - val_loss: 0.5301
#
# Fold: 15
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 106ms/step - loss: 0.4782 - val_loss: 0.2252
#
# Fold: 16
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 128ms/step - loss: 0.6166 - val_loss: 0.6904
#
# Fold: 17
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 117ms/step - loss: 0.4300 - val_loss: 0.0343
#
# Fold: 18
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 108ms/step - loss: 0.5267 - val_loss: 0.1911
#
# Fold: 19
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 110ms/step - loss: 0.4737 - val_loss: 6.2240e-05
#
# Fold: 20
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 113ms/step - loss: 0.5281 - val_loss: 0.0480
#
# Fold: 21
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 117ms/step - loss: 0.4218 - val_loss: 0.1785
#
# Fold: 22
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 109ms/step - loss: 0.6561 - val_loss: 0.1208
#
# Fold: 23
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 126ms/step - loss: 0.5540 - val_loss: 0.0858
#
# Fold: 24
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 14s 260ms/step - loss: 0.4121 - val_loss: 0.0100
#
# Fold: 25
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 138ms/step - loss: 0.5010 - val_loss: 0.0392
#
# Fold: 26
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 6s 117ms/step - loss: 0.5330 - val_loss: 0.1836
#
# Fold: 27
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 122ms/step - loss: 0.5390 - val_loss: 0.0287
#
# Fold: 28
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 122ms/step - loss: 0.4475 - val_loss: 0.1042
#
# Fold: 29
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 121ms/step - loss: 0.5443 - val_loss: 0.1245
#
# Fold: 30
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 125ms/step - loss: 0.4439 - val_loss: 0.4069
#
# Fold: 31
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 132ms/step - loss: 0.5254 - val_loss: 0.0424
#
# Fold: 32
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 127ms/step - loss: 0.4491 - val_loss: 0.3223
#
# Fold: 33
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 138ms/step - loss: 0.4905 - val_loss: 0.2732
#
# Fold: 34
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 131ms/step - loss: 0.4706 - val_loss: 0.1528
#
# Fold: 35
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 125ms/step - loss: 0.4729 - val_loss: 0.0068
#
# Fold: 36
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 129ms/step - loss: 0.4304 - val_loss: 0.0251
#
# Fold: 37
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 136ms/step - loss: 0.3816 - val_loss: 0.2433
#
# Fold: 38
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 8s 153ms/step - loss: 0.4642 - val_loss: 0.9147
#
# Fold: 39
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 134ms/step - loss: 0.3466 - val_loss: 0.0350
#
# Fold: 40
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 129ms/step - loss: 0.4524 - val_loss: 2.7224e-04
#
# Fold: 41
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 126ms/step - loss: 0.5265 - val_loss: 2.5842
#
# Fold: 42
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 130ms/step - loss: 0.4571 - val_loss: 0.5558
#
# Fold: 43
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 131ms/step - loss: 0.4763 - val_loss: 0.0218
#
# Fold: 44
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 133ms/step - loss: 0.4701 - val_loss: 0.0851
#
# Fold: 45
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 136ms/step - loss: 0.5253 - val_loss: 0.0011
#
# Fold: 46
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 8s 148ms/step - loss: 0.5354 - val_loss: 0.7466
#
# Fold: 47
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 9s 160ms/step - loss: 0.4139 - val_loss: 0.4413
#
# Fold: 48
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 136ms/step - loss: 0.5500 - val_loss: 1.0484
#
# Fold: 49
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 9s 162ms/step - loss: 0.5822 - val_loss: 0.8355
#
# Fold: 50
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 137ms/step - loss: 0.5632 - val_loss: 1.1199
#
# Fold: 51
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 8s 156ms/step - loss: 0.4121 - val_loss: 0.0132
#
# Fold: 52
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 9s 158ms/step - loss: 0.4258 - val_loss: 0.0064
#
# Fold: 53
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 8s 146ms/step - loss: 0.5429 - val_loss: 0.7559
# Fold: 54
# Train on 54 samples, validate on 1 samples
# Epoch 1/1
# 54/54 [==============================] - 7s 136ms/step - loss: 0.5182 - val_loss: 0.3032

# %%
plt.figure(figsize=(16, 8))
plt.plot(range(len(results_loss)), results_loss, 'k')
plt.plot(range(len(results_loss)), results_loss, 'ko')
plt.plot(range(len(results_val_loss)), results_val_loss, 'r')
plt.plot(range(len(results_val_loss)), results_val_loss, 'ro')
plt.legend(['loss', '', 'val_loss', ''], fontsize=20)
plt.xlabel('Fold #', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.title(f'loss: {results_loss[-1]} / val_loss: {results_val_loss[-1]}', fontsize=20)
plt.yscale('log')
plt.grid(True)
plt.show()

plt.figure(figsize=(16, 8))
plt.plot(range(len(results_loss)), results_loss, 'k')
plt.plot(range(len(results_loss)), results_loss, 'ko')
plt.plot(range(len(results_val_loss)), results_val_loss, 'r')
plt.plot(range(len(results_val_loss)), results_val_loss, 'ro')
plt.legend(['loss', '', 'val_loss', ''], fontsize=20)
plt.xlabel('Fold #', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.title(f'loss: {results_loss[-1]} / val_loss: {results_val_loss[-1]}', fontsize=20)
plt.grid(True)
plt.show()

print(f'Stats: Mean (std)')
print(f'loss: {results_loss.mean()} ({results_loss.std()})')
print(f'val_loss: {results_val_loss.mean()} ({results_val_loss.std()})')
# Out:
# Stats: Mean (std)
# loss: 0.47480348638989506 (0.06758487866865209)
# val_loss: 0.3094930917660928 (0.46890231536323024)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tcc_utils
import tratamento_dados_empresa
from sklearn.preprocessing import StandardScaler
from keras.initializers import glorot_normal as gl_normal
from sklearn.model_selection import KFold

x_csv_path = '../data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = '../data/grendene-cotacao-raw.csv'

x, y = tratamento_dados_empresa.get_x_y(x_csv_path, y_csv_path)


# Feature Scaling X
x_scaler = StandardScaler()
x = x_scaler.fit_transform(x)

# Feature Scaling y
y_scaler = StandardScaler()
y = y_scaler.fit_transform(y)

# Generate hidden layer # of nodes
number_hidden_layer = round(x.shape[1]*1.5)

# LOOCV: k-fold cross validation (folds=x.shape[0], shuffle=True, seed=1)
kfold = KFold(x.shape[0], True, 1)

# Neural Network layers
layers = [number_hidden_layer, number_hidden_layer]
activations = ['relu', 'relu']

i = 0
results_loss = np.array([])
#results_val_loss = np.array([])

results_evaluate = np.array([])

df = {'Prediction': [0], 'Real': [0], '% error': [0]}
results_predictions = pd.DataFrame(data=df)

for train, test in kfold.split(x):
    print(f'Fold: {i}')
    i += 1
    
    glorot_normal = gl_normal(seed=0)
    deep_model = tcc_utils.deep_model(x, glorot_normal, layers, activations)
    
    deep_history = deep_model.fit(x[train,:], y[train,:], batch_size=4, epochs=10, verbose=0)
    
    results_loss = np.append([results_loss], [[deep_history.history["loss"][-1]]])
    #results_val_loss = np.append([results_val_loss], [[deep_history.history["val_loss"][-1]]])
    
    evaluate = deep_model.evaluate(x[test,:], y[test,:])
    results_evaluate = np.append([results_evaluate], [[evaluate]])
    
    prediction_results = tcc_utils.prediction_results_data_frame(x[test,:], y[test,:], deep_model, y_scaler)
    print(f'Results: {prediction_results}')
    results_predictions = results_predictions.append(prediction_results, ignore_index=True)
    print('')
# Out:
# Fold: 0
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    4.178923  4.785659  12.678206
#
# Fold: 1
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real   % error
# 0    2.603777  0.900556  189.1298
#
# Fold: 2
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real  % error
# 0    2.851027  3.003443  5.07473
#
# Fold: 3
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real   % error
# 0    7.670668  7.084401  8.275451
#
# Fold: 4
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0     5.01822  4.505757  11.373505
#
# Fold: 5
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real   % error
# 0    4.780108  4.571799  4.556393
#
# Fold: 6
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real   % error
# 0    8.707286  8.770985  0.726245
#
# Fold: 7
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0     4.19616  4.764059  11.920485
#
# Fold: 8
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real   % error
# 0    3.671694  3.491649  5.156443
#
# Fold: 9
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    2.601241  1.955139  33.046376
#
# Fold: 10
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real   % error
# 0    8.416484  8.106093  3.829112
#
# Fold: 11
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    2.970486  4.328178  31.368657
#
# Fold: 12
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real   % error
# 0    1.336279  0.918108  45.54704
#
# Fold: 13
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    0.989462  1.175294  15.811496
#
# Fold: 14
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real    % error
# 0    5.456214  4.616062  18.200614
#
# Fold: 15
# 1/1 [==============================] - 6s 6s/step
# Results:    Prediction      Real    % error
# 0    6.891128  8.075241  14.663499
#
# Fold: 16
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real   % error
# 0     8.35482  7.666291  8.981263
#
# Fold: 17
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real   % error
# 0    1.888811  2.012524  6.147154
#
# Fold: 18
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    7.188569  5.928323  21.258058
#
# Fold: 19
# 1/1 [==============================] - 9s 9s/step
# Results:    Prediction      Real    % error
# 0    4.451025  5.281612  15.726007
#
# Fold: 20
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real   % error
# 0    2.025266  1.898384  6.683665
#
# Fold: 21
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real  % error
# 0    3.541126  3.601705  1.68195
#
# Fold: 22
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real    % error
# 0    1.334391  1.014859  31.485388
#
# Fold: 23
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real    % error
# 0    2.177752  1.598304  36.253956
#
# Fold: 24
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    7.415987  8.491036  12.660992
#
# Fold: 25
# 1/1 [==============================] - 6s 6s/step
# Results:    Prediction      Real   % error
# 0    4.473069  4.297708  4.080338
#
# Fold: 26
# 1/1 [==============================] - 6s 6s/step
# Results:    Prediction      Real   % error
# 0    1.414209  1.503906  5.964297
#
# Fold: 27
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction     Real   % error
# 0    7.505482  6.91761  8.498187
#
# Fold: 28
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real    % error
# 0    3.044637  3.669486  17.028248
#
# Fold: 29
# 1/1 [==============================] - 8s 8s/step
# Results:    Prediction      Real    % error
# 0    3.315043  1.798002  84.373644
#
# Fold: 30
# 1/1 [==============================] - 7s 7s/step
# Results:    Prediction     Real    % error
# 0    1.585866  1.37793  15.090437
#
# Fold: 31
# 1/1 [==============================] - 6s 6s/step
# Results:    Prediction      Real    % error
# 0     5.52581  4.492191  23.009233
#
# Fold: 32
# 1/1 [==============================] - 6s 6s/step
# Results:    Prediction      Real  % error
# 0    1.492485  1.611084  7.36145
#
# Fold: 33
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0     4.11883  4.900166  15.945091
#
# Fold: 34
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    5.842602  4.564561  27.999207
#
# Fold: 35
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real   % error
# 0    8.081464  7.693247  5.046208
#
# Fold: 36
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction     Real   % error
# 0    4.456208  4.74978  6.180763
#
# Fold: 37
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    1.200469  1.511759  20.591248
#
# Fold: 38
# 1/1 [==============================] - 8s 8s/step
# Results:    Prediction  Real   % error
# 0    7.898463  7.93  0.397695
#
# Fold: 39
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real    % error
# 0    1.418848  1.934558  26.657783
#
# Fold: 40
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real    % error
# 0    2.091353  2.388121  12.426844
#
# Fold: 41
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real    % error
# 0    0.430136  1.316158  67.318833
#
# Fold: 42
# 1/1 [==============================] - 6s 6s/step
# Results:    Prediction    Real    % error
# 0    1.674922  1.3062  28.228598
#
# Fold: 43
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real   % error
# 0    7.924217  8.434865  6.054022
#
# Fold: 44
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    0.974855  0.860367  13.306899
#
# Fold: 45
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real  % error
# 0    1.797937  1.835974  2.07176
#
# Fold: 46
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    1.391775  1.026739  35.553004
#
# Fold: 47
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0     2.51222  1.757007  42.982894
#
# Fold: 48
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real   % error
# 0    1.224231  1.311384  6.645881
#
# Fold: 49
# 1/1 [==============================] - 7s 7s/step
# Results:    Prediction      Real     % error
# 0     -0.4324  0.667981  164.732368
#
# Fold: 50
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real    % error
# 0    0.548556  1.037702  47.137416
#
# Fold: 51
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real    % error
# 0    1.825963  1.156206  57.927155
#
# Fold: 52
# 1/1 [==============================] - 5s 5s/step
# Results:    Prediction      Real    % error
# 0    1.340794  0.722523  85.571223
#
# Fold: 53
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    5.930691  5.156991  15.002948
#
# Fold: 54
# 1/1 [==============================] - 4s 4s/step
# Results:    Prediction      Real    % error
# 0    4.209251  4.794493  12.206545

# %%
plt.figure(figsize=(16, 8))
plt.plot(range(len(results_loss)), results_loss, 'k')
plt.plot(range(len(results_loss)), results_loss, 'ko')
plt.plot(range(len(results_evaluate)), results_evaluate, 'r')
plt.plot(range(len(results_evaluate)), results_evaluate, 'ro')
plt.legend(['loss', '', 'test_loss', ''], fontsize=20)
plt.xlabel('Fold #', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.title(f'loss: {results_loss[-1]} / val_loss: {results_evaluate[-1]}', fontsize=20)
plt.yscale('log')
plt.grid(True)
plt.show()

plt.figure(figsize=(16, 8))
plt.plot(range(len(results_loss)), results_loss, 'k')
plt.plot(range(len(results_loss)), results_loss, 'ko')
plt.plot(range(len(results_evaluate)), results_evaluate, 'r')
plt.plot(range(len(results_evaluate)), results_evaluate, 'ro')
plt.legend(['loss', '', 'test_loss', ''], fontsize=20)
plt.xlabel('Fold #', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.title(f'loss: {results_loss[-1]} / val_loss: {results_evaluate[-1]}', fontsize=20)
plt.grid(True)
plt.show()

print(f'Stats: Mean (std)')
print(f'loss: {results_loss.mean()} ({results_loss.std()})')
print(f'val_loss: {results_evaluate.mean()} ({results_evaluate.std()})')
# Out:
# Stats: Mean (std)
# loss: 0.003617605845502479 (0.0030514633740394807)
# val_loss: 0.07464760233970909 (0.09886512392075146)

# %%
prediction_results = results_predictions.iloc[1:,:].sort_values(by='Real', ascending=False)
# Print and plot results
print(prediction_results)
plt.plot(prediction_results['Real'], prediction_results['% error'], 'k',
             prediction_results['Real'], prediction_results['% error'], 'ro')
plt.grid(True)
plt.title(f'Error - Mean: {prediction_results["% error"].mean()}% / '
              f'Std: {prediction_results["% error"].std()}%')
plt.xlabel('Stock price')
plt.ylabel('Error (%)')
plt.show()
plt.figure(figsize=(12, 6))
plt.boxplot(prediction_results["% error"], vert=False)
plt.title(f'Error - Median: {prediction_results["% error"].median()}%')
plt.show()
print(prediction_results["% error"].describe())
# Out:
#     Prediction      Real     % error
# 7     8.707286  8.770985    0.726245
# 25    7.415987  8.491036   12.660992
# 44    7.924217  8.434865    6.054022
# 11    8.416484  8.106093    3.829112
# 16    6.891128  8.075241   14.663499
# 39    7.898463  7.930000    0.397695
# 36    8.081464  7.693247    5.046208
# 17    8.354820  7.666291    8.981263
# 4     7.670668  7.084401    8.275451
# 28    7.505482  6.917610    8.498187
# 19    7.188569  5.928323   21.258058
# 20    4.451025  5.281612   15.726007
# 54    5.930691  5.156991   15.002948
# 34    4.118830  4.900166   15.945091
# 55    4.209251  4.794493   12.206545
# 1     4.178923  4.785659   12.678206
# 8     4.196160  4.764059   11.920485
# 37    4.456208  4.749780    6.180763
# 15    5.456214  4.616062   18.200614
# 6     4.780108  4.571799    4.556393
# 35    5.842602  4.564561   27.999207
# 5     5.018220  4.505757   11.373505
# 32    5.525810  4.492191   23.009233
# 12    2.970486  4.328178   31.368657
# 26    4.473069  4.297708    4.080338
# 29    3.044637  3.669486   17.028248
# 22    3.541126  3.601705    1.681950
# 9     3.671694  3.491649    5.156443
# 3     2.851027  3.003443    5.074730
# 41    2.091353  2.388121   12.426844
# 18    1.888811  2.012524    6.147154
# 10    2.601241  1.955139   33.046376
# 40    1.418848  1.934558   26.657783
# 21    2.025266  1.898384    6.683665
# 46    1.797937  1.835974    2.071760
# 30    3.315043  1.798002   84.373644
# 48    2.512220  1.757007   42.982894
# 33    1.492485  1.611084    7.361450
# 24    2.177752  1.598304   36.253956
# 38    1.200469  1.511759   20.591248
# 27    1.414209  1.503906    5.964297
# 31    1.585866  1.377930   15.090437
# 42    0.430136  1.316158   67.318833
# 49    1.224231  1.311384    6.645881
# 43    1.674922  1.306200   28.228598
# 14    0.989462  1.175294   15.811496
# 52    1.825963  1.156206   57.927155
# 51    0.548556  1.037702   47.137416
# 47    1.391775  1.026739   35.553004
# 23    1.334391  1.014859   31.485388
# 13    1.336279  0.918108   45.547040
# 2     2.603777  0.900556  189.129800
# 45    0.974855  0.860367   13.306899
# 53    1.340794  0.722523   85.571223
# 50   -0.432400  0.667981  164.732368
# count     55.000000
# mean      25.775031
# std       35.472109
# min        0.397695
# 25%        6.413322
# 50%       14.663499
# 75%       29.798627
# max      189.129800
# Name: % error, dtype: float64

# %%
plt.plot(prediction_results['Real'], prediction_results['% error'], 'k',
             prediction_results['Real'], prediction_results['% error'], 'ro')
plt.grid(True)
plt.title(f'Error - Mean: {prediction_results["% error"].mean()}% / '
              f'Std: {prediction_results["% error"].std()}%')
plt.xlabel('Stock price')
plt.ylabel('Error (%)')
plt.yscale('log')
plt.show()

# %%
kfold.get_n_splits()
# Out:
# 55

# %%
prediction_results.head(57)
# Out:
#     Prediction      Real     % error
# 7     8.707286  8.770985    0.726245
# 25    7.415987  8.491036   12.660992
# 44    7.924217  8.434865    6.054022
# 11    8.416484  8.106093    3.829112
# 16    6.891128  8.075241   14.663499
# 39    7.898463  7.930000    0.397695
# 36    8.081464  7.693247    5.046208
# 17    8.354820  7.666291    8.981263
# 4     7.670668  7.084401    8.275451
# 28    7.505482  6.917610    8.498187
# 19    7.188569  5.928323   21.258058
# 20    4.451025  5.281612   15.726007
# 54    5.930691  5.156991   15.002948
# 34    4.118830  4.900166   15.945091
# 55    4.209251  4.794493   12.206545
# 1     4.178923  4.785659   12.678206
# 8     4.196160  4.764059   11.920485
# 37    4.456208  4.749780    6.180763
# 15    5.456214  4.616062   18.200614
# 6     4.780108  4.571799    4.556393
# 35    5.842602  4.564561   27.999207
# 5     5.018220  4.505757   11.373505
# 32    5.525810  4.492191   23.009233
# 12    2.970486  4.328178   31.368657
# 26    4.473069  4.297708    4.080338
# 29    3.044637  3.669486   17.028248
# 22    3.541126  3.601705    1.681950
# 9     3.671694  3.491649    5.156443
# 3     2.851027  3.003443    5.074730
# 41    2.091353  2.388121   12.426844
# 18    1.888811  2.012524    6.147154
# 10    2.601241  1.955139   33.046376
# 40    1.418848  1.934558   26.657783
# 21    2.025266  1.898384    6.683665
# 46    1.797937  1.835974    2.071760
# 30    3.315043  1.798002   84.373644
# 48    2.512220  1.757007   42.982894
# 33    1.492485  1.611084    7.361450
# 24    2.177752  1.598304   36.253956
# 38    1.200469  1.511759   20.591248
# 27    1.414209  1.503906    5.964297
# 31    1.585866  1.377930   15.090437
# 42    0.430136  1.316158   67.318833
# 49    1.224231  1.311384    6.645881
# 43    1.674922  1.306200   28.228598
# 14    0.989462  1.175294   15.811496
# 52    1.825963  1.156206   57.927155
# 51    0.548556  1.037702   47.137416
# 47    1.391775  1.026739   35.553004
# 23    1.334391  1.014859   31.485388
# 13    1.336279  0.918108   45.547040
# 2     2.603777  0.900556  189.129800
# 45    0.974855  0.860367   13.306899
# 53    1.340794  0.722523   85.571223
# 50   -0.432400  0.667981  164.732368
