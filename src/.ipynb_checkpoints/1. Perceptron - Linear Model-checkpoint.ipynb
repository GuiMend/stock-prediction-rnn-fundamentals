# %% [markdown]
# ### Perceptron: Linear model results using company Grendene (GRND3)
#
# **Perceptron:** The simplest and oldest model of Neuron, as we know it. Takes some inputs, sums them up, applies activation function and passes them to output layer. No magic here.
#
# <img src="../img/perceptron.png" alt="Drawing" style="width: 200px;"/>

# %%
import tcc_utils
import tratamento_dados_empresa
from keras.initializers import RandomUniform as rnd_uni

x_csv_path = '../data/grendene-indicadores-financeiros-raw.csv'
y_csv_path = '../data/grendene-cotacao-raw.csv'

X = tratamento_dados_empresa.treat_economatica_indicadores_financeiros(x_csv_path)

# Spliting test / train and Feature Scaling
x_train, x_test, y_train, y_test, x_scaler, y_scaler = tratamento_dados_empresa. \
    get_scaled_splits_and_scaler(x_csv_path, y_csv_path, 0.2, 0)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 1) Linear Model without val split
#
#   80% train / 20% test / 0% validation split
#
#   kernel_initializer: random_uniform
#
#   layers: input(X columns), output (1)
#
#   optimizer: adam
#
#   loss: MSE

# %%
# Keras Initializer with seed
random_uniform = rnd_uni(minval=-0.05, maxval=0.05, seed=0)
# Create model
linear_model = tcc_utils.linear_model(x_train, random_uniform)
# Fit model
linear_history = linear_model.fit(x_train, y_train, epochs=50, verbose=0)
# Evaluate model
tcc_utils.evaluate_model(linear_model, linear_history, x_train,
                         y_train, x_test, y_test, X, y_scaler, linear=True)
# Out:
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 57
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# None
# MSE of training: 0.0461934662678025
# MSE of testing: 0.15974508225917816
#                           feature_weight
# Não Consolidado
# EBIT / Divida Bruta %           0.083154
# VPA Valor Patr por Acao$        0.082143
# Capital de Giro $               0.078589
# Depreciacao e amortiz $         0.076075
# Prazo Med Estoques(dias)        0.074486
# Capex (inc inv)/Deprec %        0.071798
# Vendas por Acao $               0.066914
# Liquidez Corrente x             0.060710
# Capital Employed $              0.058211
# Liquidez Seca x                 0.056248
# Ciclo Operacional (dias)        0.054112
# EBITDA $                        0.051260
# Fluxo de caixa livre $          0.049732
# Prazo Med Recebim (dias)        0.049034
# Margem EBIT (Operac) %          0.040715
# Divida CP / Divida Tt %         0.037223
# Divida Bruta / Ebitda x         0.029172
# Divida Liq / Pat Liq %          0.028428
# EBIT / Desp Fin Brut x          0.027870
# Investimentos / Pat Lq %        0.027736
# Margem Liquida %                0.027595
# Margem Ebitda %                 0.024552
# Invested Capital $              0.023286
# Exigivel Tt / Receita %         0.021918
# ROIC (IC inicial) %             0.017623
# Ativo Fixo / Pat Liq %          0.016002
# ROE Rent Pat (pat inic)%        0.015942
# Deprec / Imob e Intang %        0.013557
# Alavancagem Financ x            0.013460
# Capex (incl invest) $           0.012348
# Divida Bruta / Atv Tt %         0.010865
# Margem Bruta %                  0.009145
# ROE Rent Pat(pat final)%        0.008540
# Divida liq / Ebitda x           0.008177
# Exigivel Tt / Pat Liq %         0.008097
# EBIT / Desp Fin Liq x           0.006858
# Ciclo Financeiro (dias)         0.006160
# Divida Total Bruta $            0.003808
# Prazo Med Forneced(dias)        0.002739
# LAIR + Desp Fin Liq $           0.002640
# Liquidez Geral x               -0.000554
# Exigivel Tt / Ativo Tt %       -0.001064
# Estr Cap (D/D+Pat Liq) %       -0.007769
# LPA Lucro por Acao $           -0.011794
# EBITDA por Acao $              -0.011803
# ROIC (IC medio) %              -0.017132
# ROA Rentab do Ativo %          -0.020950
# EBIT / Divida Liquida %        -0.027786
# Giro do Pat Liq x              -0.029675
# Divida Bruta / Pat Liq %       -0.029896
# Rentab Invest Subsid %         -0.040172
# ROIC (IC fim) %                -0.047940
# Alavancagem Operac x           -0.057840
# ROE Rent Pat(pat medio)%       -0.066421
# Giro do Ativo x                -0.068782
# Divida Total Liquida $         -0.083538
#     Prediction      Real     % error
# 8     7.080839  8.491036   16.608065
# 0     6.671118  8.075241   17.388003
# 7     6.672150  5.156991   29.380691
# 9     4.235994  4.785659   11.485659
# 2     5.461737  4.616062   18.320256
# 1     3.847887  3.669486    4.861748
# 6     4.987348  3.491649   42.836470
# 3     2.649369  3.003443   11.788942
# 10    1.548787  1.377930   12.399502
# 5     0.927391  0.900556    2.979801
# 4     1.772402  0.667981  165.337135
# count     11.000000
# mean      30.307843
# std       46.153335
# min        2.979801
# 25%       11.637301
# 50%       16.608065
# 75%       23.850474
# max      165.337135
# Name: % error, dtype: float64

# %% [markdown]
# ### 2) Linear Model with val split
#
# 72% train / 20% test / <font color=red>8%</font> validation split
#
#   kernel_initializer: random_uniform
#
#   layers: input(X columns), output (1)
#
#   optimizer: adam
#
#   loss: MSE

# %%
# Keras Initializer with seed
random_uniform = rnd_uni(minval=-0.05, maxval=0.05, seed=0)
# Create model
linear_model_with_val = tcc_utils.linear_model(x_train, random_uniform)
# Fit model
linear_history_with_val = linear_model_with_val.fit(x_train, y_train, epochs=50,
                                                    validation_split=0.1, verbose=0)
# Evaluate model
tcc_utils.evaluate_model(linear_model_with_val, linear_history_with_val, x_train,
                         y_train, x_test, y_test, X, y_scaler, val=True, linear=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 1)                 57
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# None
# MSE of training: 0.0444344167004932
# MSE of testing: 0.1531408429145813
#                           feature_weight
# Não Consolidado
# EBIT / Divida Bruta %           0.084948
# VPA Valor Patr por Acao$        0.083223
# Capital de Giro $               0.079926
# Depreciacao e amortiz $         0.076276
# Capex (inc inv)/Deprec %        0.071904
# Prazo Med Estoques(dias)        0.070891
# Vendas por Acao $               0.067820
# Liquidez Corrente x             0.059630
# Capital Employed $              0.059265
# Liquidez Seca x                 0.055408
# Fluxo de caixa livre $          0.053980
# EBITDA $                        0.052742
# Ciclo Operacional (dias)        0.051223
# Prazo Med Recebim (dias)        0.045802
# Margem EBIT (Operac) %          0.042848
# Divida CP / Divida Tt %         0.029398
# Divida Bruta / Ebitda x         0.028794
# Margem Ebitda %                 0.028337
# Margem Liquida %                0.027847
# EBIT / Desp Fin Brut x          0.027412
# Divida Liq / Pat Liq %          0.026572
# Investimentos / Pat Lq %        0.025505
# Invested Capital $              0.023837
# Exigivel Tt / Receita %         0.022896
# Alavancagem Financ x            0.019610
# ROIC (IC inicial) %             0.018993
# Ativo Fixo / Pat Liq %          0.013528
# Capex (incl invest) $           0.012820
# Prazo Med Forneced(dias)        0.011349
# Margem Bruta %                  0.010900
# ROE Rent Pat (pat inic)%        0.010442
# Divida Bruta / Atv Tt %         0.010201
# Deprec / Imob e Intang %        0.009188
# Exigivel Tt / Pat Liq %         0.008145
# Divida liq / Ebitda x           0.005790
# LAIR + Desp Fin Liq $           0.004212
# Divida Total Bruta $            0.003677
# ROE Rent Pat(pat final)%        0.002940
# Ciclo Financeiro (dias)         0.002330
# Liquidez Geral x               -0.000258
# EBIT / Desp Fin Liq x          -0.001192
# Exigivel Tt / Ativo Tt %       -0.001325
# Estr Cap (D/D+Pat Liq) %       -0.008493
# LPA Lucro por Acao $           -0.010311
# EBITDA por Acao $              -0.010320
# ROIC (IC medio) %              -0.015397
# ROA Rentab do Ativo %          -0.023879
# EBIT / Divida Liquida %        -0.028872
# Divida Bruta / Pat Liq %       -0.030060
# Giro do Pat Liq x              -0.031289
# Rentab Invest Subsid %         -0.043680
# ROIC (IC fim) %                -0.045555
# Alavancagem Operac x           -0.061944
# Giro do Ativo x                -0.070892
# ROE Rent Pat(pat medio)%       -0.072122
# Divida Total Liquida $         -0.085598
#     Prediction      Real     % error
# 8     7.115225  8.491036   16.203095
# 0     6.712085  8.075241   16.880687
# 7     6.747423  5.156991   30.840313
# 9     4.176411  4.785659   12.730696
# 2     5.426741  4.616062   17.562120
# 1     3.783152  3.669486    3.097600
# 6     4.859031  3.491649   39.161505
# 3     2.574620  3.003443   14.277726
# 10    1.514632  1.377930    9.920810
# 5     0.906095  0.900556    0.615012
# 4     1.703202  0.667981  154.977572
# count     11.000000
# mean      28.751558
# std       43.289571
# min        0.615012
# 25%       11.325753
# 50%       16.203095
# 75%       24.201217
# max      154.977572
# Name: % error, dtype: float64
